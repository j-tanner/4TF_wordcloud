# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
from PIL import Image
import matplotlib.pyplot as plt
import re

# %%
f = open('genres_improved.txt', 'r')

# %%
artists = f.read()

# %%
artists
# Out:
# "bitlate: []\nOlive Amun: []\nLorelei: []\nThe Raconteurs: ['alternative rock', 'garage rock', 'garage rock revival', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'rock', 'supergroup']\nedapollo: ['vapor twitch']\nFergus James: ['australian alternative pop', 'australian pop']\nWongo: ['australian house', 'bass house', 'fidget house']\nBlak Trash: []\nTycho: ['chillwave', 'downtempo', 'electronica', 'indietronica', 'intelligent dance music']\nSaint Sinner: ['downtempo bass']\nMargaret Glaspy: ['indie pop']\nPVRIS: ['electropop', 'modern alternative rock', 'modern rock', 'pixie', 'pop', 'pop emo', 'pop punk', 'rock']\nOrder Sixty6: []\nTones And I: ['australian pop']\nCosmo Sheldrake: ['uk pop']\nRed Hearse: []\nMillie Turner: ['uk alternative pop']\nJacob Collier: ['indie soul', 'uk alternative pop']\nJoJo: ['dance pop', 'hip pop', 'pop', 'pop dance', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary']\nTobe Nwigwe: ['christian hip hop', 'houston rap']\nLANELL GRANT: []\nClairo: ['bedroom pop', 'boston indie']\nHIRIE: ['jawaiian', 'reggae rock']\nSlightly Stoopid: ['reggae fusion', 'reggae rock']\nNinajirachi: ['aussietronica']\nOh Boy: ['aussietronica']\nJonah Yano: []\nBADBADNOTGOOD: ['alternative hip hop', 'canadian modern jazz', 'escape room', 'funk', 'hip hop', 'indie soul']\nEGOISM: ['sydney indie']\nLANY: ['la pop', 'pop']\nPsychedelic Porn Crumpets: ['australian garage punk', 'australian psych', 'neo-psychedelic']\nFila Brazillia: ['big beat', 'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop']\nHazlett: ['brisbane indie', 'indie anthem-folk']\nMoon Loves Honey: ['danish indie pop']\nAndrew Bird: ['art pop', 'baroque pop', 'chamber pop', 'chicago indie', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'melancholia', 'stomp and holler']\nRyan Dominic: []\nblink-182: ['pop punk', 'punk', 'socal pop punk']\nA R I Z O N A: ['edm', 'electropop', 'indie poptimism', 'pop', 'pop dance', 'pop edm', 'tropical house']\nBUNT.: ['deep tropical house', 'pop edm', 'tropical house']\nThe Dip: ['deep new americana', 'funk', 'indie folk', 'retro soul']\nAudien: ['big room', 'edm', 'electro house', 'electropop', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'tropical house']\nLiam O'Donnell: []\nDVNA: ['australian alternative pop']\nPacific Avenue: ['australian garage punk', 'australian indie rock']\nStill Woozy: ['bedroom pop', 'modern rock', 'oakland indie', 'pop']\nAmadou & Mariam feat. Santigold: []\nSantigold: ['alternative dance', 'dance-punk', 'electropop', 'escape room', 'new rave']\nBAYNK: ['alternative r&b', 'edm', 'electropop', 'indie electropop', 'indie soul', 'tropical house', 'vapor soul', 'vapor twitch']\nSinead Harnett: ['alternative r&b', 'gauze pop', 'indie r&b', 'indie soul', 'uk contemporary r&b']\nDaju: []\nElephant Gym: ['instrumental math rock', 'southeast asian post-rock', 'taiwan indie']\nBOI: []\nLogic: ['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap']\nFirst Beige: ['australian indie rock', 'brisbane indie']\nLil Spacely: ['australian hip hop', 'australian trap']\nBig Skeez: ['australian trap']\nRico Pacino: []\nJustin Caruso: ['deep tropical house', 'electropop', 'pop dance', 'pop edm']\nMædi: []\nVin Bogart: []\nNo-uh: []\nJason Price: []\nMasked Wolf: ['australian hip hop']\nPrice: []\nJ.B. Boone: []\nMarmozets: ['british alternative rock', 'modern alternative rock', 'modern rock', 'pixie', 'pop emo']\nGuster: ['boston rock', 'neo mellow', 'pop rock']\nLane 8: ['gauze pop', 'progressive house', 'tropical house']\nPOLIÇA: ['art pop', 'chillwave', 'electropop', 'metropopolis', 'shimmer pop']\nSyd Arthur: ['kent indie']\nSan Mei: ['vapor pop']\nJack Botts: ['australian indie folk', 'indie anthem-folk']\nTSHA: ['uk house']\nSnarky Puppy: ['contemporary jazz', 'funk rock', 'jazz funk', 'jazz fusion', 'progressive jazz fusion']\nSG Lewis: ['alternative r&b', 'edm', 'indie soul', 'pop', 'uk dance', 'vapor soul' ...

# %%
artists = artists.split('\n')

# %%
artists
# Out:
# ['bitlate: []',
#  'Olive Amun: []',
#  'Lorelei: []',
#  "The Raconteurs: ['alternative rock', 'garage rock', 'garage rock revival', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'rock', 'supergroup']",
#  "edapollo: ['vapor twitch']",
#  "Fergus James: ['australian alternative pop', 'australian pop']",
#  "Wongo: ['australian house', 'bass house', 'fidget house']",
#  'Blak Trash: []',
#  "Tycho: ['chillwave', 'downtempo', 'electronica', 'indietronica', 'intelligent dance music']",
#  "Saint Sinner: ['downtempo bass']",
#  "Margaret Glaspy: ['indie pop']",
#  "PVRIS: ['electropop', 'modern alternative rock', 'modern rock', 'pixie', 'pop', 'pop emo', 'pop punk', 'rock']",
#  'Order Sixty6: []',
#  "Tones And I: ['australian pop']",
#  "Cosmo Sheldrake: ['uk pop']",
#  'Red Hearse: []',
#  "Millie Turner: ['uk alternative pop']",
#  "Jacob Collier: ['indie soul', 'uk alternative pop']",
#  "JoJo: ['dance pop', 'hip pop', 'pop', 'pop dance', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary']",
#  "Tobe Nwigwe: ['christian hip hop', 'houston rap']",
#  'LANELL GRANT: []',
#  "Clairo: ['bedroom pop', 'boston indie']",
#  "HIRIE: ['jawaiian', 'reggae rock']",
#  "Slightly Stoopid: ['reggae fusion', 'reggae rock']",
#  "Ninajirachi: ['aussietronica']",
#  "Oh Boy: ['aussietronica']",
#  'Jonah Yano: []',
#  "BADBADNOTGOOD: ['alternative hip hop', 'canadian modern jazz', 'escape room', 'funk', 'hip hop', 'indie soul']",
#  "EGOISM: ['sydney indie']",
#  "LANY: ['la pop', 'pop']",
#  "Psychedelic Porn Crumpets: ['australian garage punk', 'australian psych', 'neo-psychedelic']",
#  "Fila Brazillia: ['big beat', 'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop']",
#  "Hazlett: ['brisbane indie', 'indie anthem-folk']",
#  "Moon Loves Honey: ['danish indie pop']",
#  "Andrew Bird: ['art pop', 'baroque pop', 'chamber pop', 'chicago indie', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'melancholia', 'stomp and holler']",
#  'Ryan Dominic: []',
#  "blink-182: ['pop punk', 'punk', 'socal pop punk']",
#  "A R I Z O N A: ['edm', 'electropop', 'indie poptimism', 'pop', 'pop dance', 'pop edm', 'tropical house']",
#  "BUNT.: ['deep tropical house', 'pop edm', 'tropical house']",
#  "The Dip: ['deep new americana', 'funk', 'indie folk', 'retro soul']",
#  "Audien: ['big room', 'edm', 'electro house', 'electropop', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'tropical house']",
#  "Liam O'Donnell: []",
#  "DVNA: ['australian alternative pop']",
#  "Pacific Avenue: ['australian garage punk', 'australian indie rock']",
#  "Still Woozy: ['bedroom pop', 'modern rock', 'oakland indie', 'pop']",
#  'Amadou & Mariam feat. Santigold: []',
#  "Santigold: ['alternative dance', 'dance-punk', 'electropop', 'escape room', 'new rave']",
#  "BAYNK: ['alternative r&b', 'edm', 'electropop', 'indie electropop', 'indie soul', 'tropical house', 'vapor soul', 'vapor twitch']",
#  "Sinead Harnett: ['alternative r&b', 'gauze pop', 'indie r&b', 'indie soul', 'uk contemporary r&b']",
#  'Daju: []',
#  "Elephant Gym: ['instrumental math rock', 'southeast asian post-rock', 'taiwan indie']",
#  'BOI: []',
#  "Logic: ['conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap']",
#  "First Beige: ['australian indie rock', 'brisbane indie']",
#  "Lil Spacely: ['australian hip hop', 'australian trap']",
#  "Big Skeez: ['australian trap']",
#  'Rico Pacino: []',
#  "Justin Caruso: ['deep tropical house', 'electropop', 'pop dance', 'pop edm']",
#  'Mædi: []',
#  'Vin Bogart: []',
#  'No-uh: []',
#  'Jason Price: []',
#  "Masked Wolf: ['australian hip hop']",
#  'Price: []',
#  'J.B. Boone: []',
#  "Marmozets: ['british alternative rock', 'modern alternative rock', 'modern rock', 'pixie', 'pop emo']",
#  "Guster: ['boston rock', 'neo mellow', 'pop rock']",
#  "Lane 8: ['gauze pop', 'progressive house', 'tropical house']",
#  "POLIÇA: ['art pop', 'chillwave', 'electropop', 'metropopolis', 'shimmer pop']",
#  "Syd Arthur: ['kent indie']",
#  "San Mei: ['vapor pop']",
#  "Jack Botts: ['australian indie folk', 'indie anthem-folk']",
#  "TSHA: ['uk house']",
#  "Snarky Puppy: ['contemporary jazz', 'funk rock', 'jazz funk', 'jazz fusion', 'progressive jazz fusion']",
#  "SG Lewis: ['alternative r&b', 'edm', 'indie soul', 'pop', 'uk dance', 'vapor soul']",
#  "Clairo: ['bedroom pop', 'boston indie']",
#  "Allday: ['australian hip hop', 'australian indie', 'australian pop', 'australian trap']",
#  "Japanese Wallpaper: ['australian indie', 'indie dream pop']",
#  "Bad Bad Hats: ['bubblegrunge', 'indie pop', 'indie rock', 'minneapolis indie']",
#  "Above & Beyond: ['edm', 'progressive house', 'progressive trance', 'trance', 'uplifting trance']",
#  'Richard Bedford: []',
#  "EDEN: ['electropop', 'indie poptimism', 'modern rock', 'pop']",
#  "Lupe Fiasco: ['chicago rap', 'conscious hip hop', 'hip hop', 'political hip hop', 'pop rap', 'rap', 'southern hip hop']",
#  "Troi Irons: ['indie electropop']",
#  'Mr. Popular: []',
#  "Tobiahs: ['aussietronica']",
#  "TOWNS: ['adelaide indie', 'australian garage punk', 'garage psych']",
#  "FKJ: ['filter house', 'indie soul']",
#  "Zach Winters: ['christian indie', 'indiecoustica', 'ok indie']",
#  "Fenech-Soler: ['alternative dance', 'electrofox', 'indie poptimism', 'metropopolis', 'northamptonshire indie', 'shimmer pop']",
#  "Post Malone: ['dfw rap', 'melodic rap', 'rap']",
#  "San Cisco: ['australian indie', 'australian pop', 'fremantle indie', 'metropopolis', 'perth indie']",
#  "Bop Alloy: ['ambeat']",
#  "Substantial: ['ambeat']",
#  "Marcus D: ['ambeat', 'chillhop']",
#  "Mr. SOS: ['underground rap']",
#  "Cise Star: ['ambeat']",
#  'MARSHES: []',
#  "Jeremy Blake: ['focus beats']",
#  "Introvert: ['aussie emo', 'australian post-hardcore', 'newcastle nsw indie']",
#  "Sylvan Esso: ['electropop', 'etherpop', 'indie folk', 'indie pop', 'indie rock']",
#  "Lime Cordiale: ['australian indie', 'australian pop']",
#  "In Love With a Ghost: ['kawaii future bass', 'lo-fi beats']",
#  'Nori: []',
#  'Liz Bills: []',
#  "The Japanese House: ['electropop', 'indie pop', 'indie poptimism', 'indietronica', 'modern dream pop', 'vapor soul']",
#  "Interpol: ['alternative dance', 'alternative rock', 'dance-punk', 'indie rock', 'modern rock', 'new rave', 'rock']",
#  "Wafia: ['australian indie', 'australian pop']",
#  'Hizuru: []',
#  "Nujabes: ['chillhop', 'downtempo', 'japanese chillhop', 'jazz rap']",
#  'Cise Star: []',
#  'Akin: []',
#  'YAS: []',
#  'Valntn: []',
#  'Emilia Ali: []',
#  'nøll: []',
#  "damnboy!: ['hawaiian hip hop']",
#  "The Tech Thieves: ['bass trap', 'modern alternative rock', 'traprun']",
#  'Frameworks: []',
#  "Spacey Jane: ['australian garage punk', 'australian indie', 'australian indie rock', 'fremantle indie', 'perth indie']",
#  "Tame Impala: ['australian psych', 'neo-psychedelic']",
#  "Bend Sinister: ['canadian indie', 'kelowna bc indie', 'vancouver indie']",
#  "Billie Eilish: ['electropop', 'pop']",
#  "Almond Soy: ['australian indie rock']",
#  'Sister: []',
#  "The Cat Empire: ['australian reggae fusion', 'australian ska', 'ska jazz']",
#  "Big Thief: ['art pop', 'brooklyn indie', 'chamber pop', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'small room', 'stomp and holler']",
#  "French 79: ['electronica', 'french indie pop', 'french indietronica', 'new french touch']",
#  'Sarah Rebecca: []',
#  "The Zolas: ['canadian indie', 'indie rock', 'vancouver indie']",
#  "Fractures: ['indie anthem-folk', 'vapor soul']",
#  "Timberwolf: ['adelaide indie']",
#  "Hooligan Hefs: ['aussie drill', 'australian trap']",
#  "Hooligan Skinny: ['aussie drill']",
#  "The Album Leaf: ['american post-rock', 'compositional ambient', 'post-rock']",
#  "Tune-Yards: ['art pop', 'freak folk', 'indie pop', 'indie rock', 'one-person band']",
#  "Ashley Alexander: ['nz pop']",
#  "Osvaldorio: ['indonesian edm']",
#  'Wiana: []',
#  "Galdive: ['indonesian indie']",
#  "Kedam: ['new french touch']",
#  'Lamalo: []',
#  "Kim Ven: ['australian alternative pop']",
#  'Great Time: []',
#  "Tacky Annie: ['minneapolis indie']",
#  "Sam Burchfield: ['deep new americana', 'indiecoustica', 'stomp and holler']",
#  "Black Pistol Fire: ['alternative roots rock', 'garage rock', 'modern alternative rock', 'modern blues rock', 'modern hard rock', 'modern rock', 'punk blues', 'rock']",
#  "Bonobo: ['downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop']",
#  "Maribou State: ['electronica', 'future garage', 'indie soul']",
#  "Björk: ['alternative dance', 'art pop', 'dance pop', 'electronica', 'experimental pop', 'experimental vocal', 'icelandic experimental', 'icelandic pop', 'metropopolis', 'permanent wave', 'trip hop']",
#  "Teebs: ['bass music', 'chillwave', 'electronica', 'microhouse', 'ninja', 'wonky']",
#  "Sudan Archives: ['afrofuturism', 'alternative r&b', 'art pop', 'escape room', 'indie soul', 'la pop']",
#  "Apollo Bebop: ['oc indie']",
#  "Parisalexa: ['alternative r&b', 'indie r&b']",
#  'Quincy Morales: []',
#  'Rebecca Hatch: []',
#  "Sandy's: []",
#  "Mac Miller: ['hip hop', 'pittsburgh rap', 'rap']",
#  "Jai Paul: ['art pop', 'chillwave', 'electronica', 'indie soul']",
#  "Queen Ifrica: ['dancehall', 'lovers rock', 'modern reggae', 'reggae fusion', 'roots reggae']",
#  'Hayley Williams: []',
#  "Mint Julep: ['indie dream pop', 'indie shoegaze', 'metropopolis']",
#  "Sumner: ['tassie indie']",
#  "Queens of the Stone Age: ['alternative metal', 'alternative rock', 'blues rock', 'modern rock', 'nu metal', 'palm desert scene', 'rock', 'stoner metal', 'stoner rock']",
#  "Phoenix: ['alternative dance', 'dance-punk', 'indie pop', 'indie rock', 'modern rock', 'new rave', 'rock', 'rock independant francais']",
#  "Broods: ['auckland indie', 'electropop', 'etherpop', 'indie electropop', 'indie pop', 'indie poptimism', 'indietronica', 'metropopolis', 'nz pop', 'pop', 'shimmer pop', 'tropical house', 'vapor soul']",
#  "Cro: ['german hip hop', 'german pop', 'pop rap']",
#  "Teesy: ['german pop', 'german r&b']",
#  "My Brothers And I: ['indie cafe pop', 'indiecoustica']",
#  "Cautious Clay: ['alternative r&b', 'chill r&b', 'indie r&b', 'nyc pop', 'pop', 'vapor soul']",
#  "isaac gracie: ['indie anthem-folk', 'indie folk']",
#  "Hippo Campus: ['indie pop', 'indie poptimism', 'indie rock', 'minneapolis indie', 'modern alternative rock', 'modern rock']",
#  "Litany: ['electropop', 'indie electropop', 'indie pop', 'indie poptimism', 'indie soul', 'vapor soul']",
#  'JAKE: []',
#  "Tunnel Vision: ['modern ska punk']",
#  'Angela Hunte: []',
#  "Jess Day: ['adelaide indie']",
#  "E^ST: ['australian indie', 'australian pop']",
#  "il:lo: ['chillstep', 'vapor twitch']",
#  "BENEE: ['nz pop', 'pop']",
#  "Ruby Fields: ['australian garage punk', 'australian indie', 'australian pop']",
#  "Thees Uhlmann: ['german indie', 'german pop', 'german rock']",
#  "ROLE MODEL: ['alternative r&b', 'bedroom pop', 'indie cafe pop', 'indie pop', 'pop']",
#  "LION BABE: ['alternative r&b', 'escape room', 'indie r&b', 'indie soul', 'neo soul']",
#  "Childish Gambino: ['atl hip hop', 'hip hop', 'pop rap', 'rap']",
#  "Oddisee: ['alternative hip hop', 'dmv rap', 'hip hop', 'sudanese pop']",
#  "The Whitest Boy Alive: ['alternative dance', 'dance-punk', 'electronica', 'new rave']",
#  'Hope D: []',
#  "The Shang: ['australian indie rock']",
#  'Eluera: []',
#  "Rainbow Kitten Surprise: ['indie folk', 'indie rock', 'modern alternative rock', 'modern rock', 'stomp and holler']",
#  "Pickwick: ['seattle indie']",
#  'Bravo: []',
#  "Qveen Herby: ['dance pop', 'electropop', 'escape room', 'pop', 'post-teen pop', 'trap queen']",
#  "SONTALK: ['nashville indie']",
#  "The Expendables: ['reggae rock']",
#  "STS9: ['jam band', 'jamtronica', 'livetronica']",
#  "London Grammar: ['metropopolis', 'nottingham indie']",
#  "Purity Ring: ['art pop', 'canadian electropop', 'chillwave', 'edmonton indie', 'electropop', 'grave wave', 'indietronica', 'metropopolis', 'shimmer pop', 'vapor soul']",
#  "Bad Snacks: ['downtempo bass']",
#  "Tom Misch: ['indie soul', 'jazz pop']",
#  "Carmody: ['british soul', 'uk alternative pop']",
#  'Vetta Borne: []',
#  "RÜFÜS DU SOL: ['australian electropop', 'edm', 'indietronica']",
#  'Mia Rodriguez: []',
#  "Télépopmusik: ['downtempo', 'electronica', 'nu jazz', 'trip hop']",
#  "Juice Aleem: ['birmingham hip hop']",
#  "Catastrophe & Cure: ['vienna indie']",
#  'Love Supreme: []',
#  "Suckers: ['baroque pop', 'brooklyn indie']",
#  "Kishi Bashi: ['indie folk', 'indie pop', 'metropopolis', 'shimmer pop', 'stomp and holler', 'stomp and whittle']",
#  "Flipturn: ['jacksonville indie', 'modern rock']",
#  "Man Man: ['freak folk', 'philly indie', 'stomp and holler']",
#  "Nothing But Thieves: ['alternative pop rock', 'modern alternative rock', 'modern rock', 'rock']",
#  'Nardean: []',
#  'Austin Millz: []',
#  "Pell: ['underground hip hop']",
#  "L'Impératrice: ['french indie pop', 'french indietronica', 'french synthpop', 'indie soul', 'new french touch']",
#  'Self Tape: []',
#  "Bremer/McCoy: ['danish jazz', 'danish modern jazz']",
#  'Hayfitz: []',
#  "Mija: ['electra']",
#  "Dirty Heads: ['reggae fusion', 'reggae rock']",
#  "Kaleida: ['electropop', 'metropopolis', 'vapor pop']",
#  'Planet Vegeta: []',
#  "La Belle Vie: ['new french touch']",
#  "YONAS: ['deep underground hip hop', 'indie pop rap', 'pop rap']",
#  "SwuM: ['chillhop', 'lo-fi beats']",
#  "JAWS: ['birmingham indie', 'english indie rock', 'modern alternative rock', 'modern rock']",
#  "Witt Lowry: ['pop rap']",
#  "RJD2: ['alternative hip hop', 'big beat', 'electronica', 'hip hop', 'jazztronica', 'ninja', 'nu jazz', 'turntablism']",
#  "Pinback: ['indie pop', 'indie rock']",
#  "Winston Surfshirt: ['australian indie', 'australian pop', 'indie soul']",
#  "Timecop1983: ['cyberpunk', 'synthwave']",
#  "The Bad Dreamers: ['popwave', 'spacewave', 'synthwave']",
#  "Owl Eyes: ['australian alternative pop', 'australian indie', 'shimmer pop']",
#  'KVKA: []',
#  "Röyksopp: ['alternative dance', 'big beat', 'downtempo', 'electronica', 'electropop', 'trip hop']",
#  "Maude Latour: ['indie pop', 'nyc pop']",
#  "Flobots: ['comic', 'conscious hip hop']",
#  "Night Tales: ['australian dance']",
#  "Sweater Curse: ['australian garage punk', 'brisbane indie']",
#  'Nadamondi: []',
#  "Little Simz: ['escape room', 'indie soul', 'trap queen', 'uk alternative hip hop']",
#  "The Staple Singers: ['chicago soul', 'classic soul', 'funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'southern soul']",
#  "The Seige: ['cali rap', 'modern alternative rock']",
#  "Big Freedia: ['bounce', 'escape room', 'lgbtq+ hip hop', 'new orleans rap', 'trap queen']",
#  "Lizzo: ['dance pop', 'escape room', 'minnesota hip hop', 'pop', 'pop dance', 'pop rap', 'trap queen']",
#  "Black Pumas: ['retro soul']",
#  "Gaël Faye: ['french indie pop', 'french indietronica', 'new french touch']",
#  "Dom La Nena: ['nova mpb']",
#  'Rosemary Standley: []',
#  'Birds on a Wire: []',
#  "The Prussians: ['spanish modern rock']",
#  "Poolside: ['alternative dance', 'indie soul', 'new rave', 'nu disco']",
#  "Amo Amo: ['la pop']",
#  "Two Friends: ['edm', 'electropop', 'pop dance', 'pop edm', 'tropical house']",
#  "MAX: ['dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop']",
#  "Portico Quartet: ['british jazz', 'compositional ambient', 'contemporary jazz', 'electronica', 'jazz quartet', 'new tribe', 'nu jazz']",
#  "Watsky: ['abstract hip hop', 'comic', 'modern rock', 'pop rap']",
#  'Adam Newling: []',
#  'Closure: []',
#  'George Alice: []',
#  'NASAYA: []',
#  'Dharmarat: []',
#  'Almac: []',
#  "Kllo: ['alternative r&b', 'aussietronica', 'electropop', 'indie electropop', 'indie soul', 'vapor soul']",
#  "Lastlings: ['alternative dance', 'vapor soul']",
#  "Bread Club: ['australian indie']",
#  "Phil Fresh: ['australian trap']",
#  "Palatine: ['rock independant francais']",
#  "Jay Som: ['art pop', 'bay area indie', 'chillwave', 'indie folk', 'indie pop', 'indie rock', 'oakland indie', 'small room']",
#  "Japanese Breakfast: ['art pop', 'bubblegrunge', 'eugene indie', 'indie pop', 'indie rock', 'philly indie']",
#  "Angie McMahon: ['australian indie', 'australian pop']",
#  "Slightly Stoopid: ['reggae fusion', 'reggae rock']",
#  "Sir Woman: ['austindie', 'pop soul']",
#  "Speak Easy: ['st petersburg fl indie']",
#  'The Bubbles: []',
#  "Andre Nickatina: ['gangster rap', 'hyphy', 'west coast rap', 'west coast trap']",
#  'BLOW: []',
#  "Ibrahim Maalouf: ['arabic jazz', 'french jazz', 'jazz trumpet']",
#  "Hayden James: ['aussietronica', 'edm', 'gauze pop', 'house', 'indie soul', 'pop dance', 'tropical house']",
#  "Icona Pop: ['candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'pop dance', 'swedish electropop', 'swedish synthpop']",
#  "The Venus Project: ['nz pop']",
#  "Tritonal: ['big room', 'edm', 'electro house', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'progressive trance', 'trance', 'tropical house', 'uplifting trance']",
#  'Skyler Stonestreet: []',
#  "박혜진 Park Hye Jin: ['korean dream pop']",
#  'will hyde: []',
#  "Bad Suns: ['indie pop', 'indie poptimism', 'indie rock', 'la indie', 'modern alternative rock', 'modern rock', 'pop rock']",
#  "dodie: ['indie cafe pop', 'indie pop', 'pop']",
#  "Polyphia: ['instrumental rock']",
#  "Vallis Alps: ['australian indie', 'electropop', 'vapor soul']",
#  "Christian Löffler: ['electronica', 'hamburg electronic', 'microhouse', 'minimal techno', 'new french touch', 'organic electronic', 'pop ambient']",
#  'Noy: []',
#  "Sophiegrophy: ['australian hip hop']",
#  "Paramore: ['candy pop', 'emo', 'pixie', 'pop emo', 'pop punk']",
#  "Modjo: ['disco house', 'filter house', 'vocal house']",
#  "Fazıl Say: ['classical piano', 'turkish classical performance', 'turkish jazz']",
#  "Belle Chen: ['taiwan classical performance']",
#  "JVLY: ['australian electropop']",
#  "Smoke Season: ['vapor pop']",
#  "beabadoobee: ['bedroom pop', 'bubblegrunge', 'indie pop']",
#  "Tash Sultana: ['australian reggae fusion']",
#  "Laura Misch: ['indie jazz', 'indie soul']",
#  "Metric: ['alternative dance', 'canadian indie', 'canadian rock', 'dance-punk', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'neo-synthpop', 'new rave', 'rock', 'shimmer pop']",
#  'IJALE: []',
#  'Zephyrrgreene: []',
#  'Inspired Flight: []',
#  "Photay: ['chillwave', 'indie jazz', 'wonky']",
#  "WHARVES: ['australian indie rock']",
#  'Lafa Taylor: []',
#  'Medium Troy: []',
#  'Saving Escape: []',
#  "Goodie Mob: ['alternative hip hop', 'atl hip hop', 'conscious hip hop', 'dirty south rap', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap']",
#  "KRS-One: ['alternative hip hop', 'bronx hip hop', 'conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'old school hip hop', 'political hip hop', 'rap', 'turntablism']",
#  "Common: ['alternative hip hop', 'chicago rap', 'conscious hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'neo soul', 'political hip hop', 'rap', 'southern hip hop']",
#  "CYNE: ['ambeat', 'jazz rap', 'underground rap']",
#  'Six City: []',
#  'Ryan Nealon: []',
#  'Mr.Kitty: []',
#  "Echos: ['electropop', 'indie electropop', 'indie poptimism']",
#  "Lucy Dacus: ['art pop', 'bubblegrunge', 'indie folk', 'indie pop', 'indie rock']",
#  'More Fatter: []',
#  "clipping.: ['alternative hip hop', 'escape room', 'experimental hip hop', 'industrial hip hop']",
#  "Anna Calvi: ['art pop', 'chamber psych']",
#  "Alabaster DePlume: ['chamber psych', 'fourth world', 'indie folk', 'indie jazz', 'uk contemporary jazz']",
#  "Ali Farka Touré: ['afrobeat', 'afropop', 'desert blues', 'malian blues', 'mande pop', 'world']",
#  "Ry Cooder: ['blues', 'blues rock', 'country blues', 'country rock', 'folk', 'folk rock', 'mellow gold', 'piedmont blues', 'roots rock', 'singer-songwriter', 'traditional folk']",
#  "Bahamas: ['canadian indie', 'indie folk', 'indie pop', 'new americana', 'stomp and holler']",
#  "Mark Tarmonea: ['german house']",
#  'Yannek Maunz: []',
#  "Louis The Child: ['edm', 'electropop', 'pop', 'pop dance', 'tropical house']",
#  "Ashe: ['electropop', 'indie pop', 'pop']",
#  "The Naked And Famous: ['alternative dance', 'auckland indie', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'kiwi rock', 'metropopolis', 'modern rock', 'shimmer pop']",
#  "Pete Fountain: ['dixieland', 'jazz clarinet', 'new orleans jazz']",
#  "The Fretless: ['irish neo-traditional']",
#  "Jaguar Jonze: ['brisbane indie']",
#  "Teenage Dads: ['australian garage punk']",
#  "Emancipator: ['downtempo', 'electronica', 'livetronica', 'trip hop']",
#  'Hazy: []',
#  'Narli: []',
#  "JK-47: ['australian hip hop']",
#  "HÆLOS: ['alternative dance', 'electronica']",
#  "Orville Peck: ['alternative country', 'queer country']",
#  'AYA YVES: []',
#  "Philippe Katerine: ['chanson', 'french indie pop', 'french indietronica', 'french rock', 'nouvelle chanson francaise']",
#  "Angèle: ['belgian pop', 'variete francaise']",
#  "Chilly Gonzales: ['neo-classical']",
#  "Pantha Du Prince: ['electronica', 'hamburg electronic', 'microhouse', 'minimal techno']",
#  "Dumbfoundead: ['asian american hip hop', 'battle rap', 'k-rap']",
#  'Wax: []',
#  'Breezy Lovejoy: []',
#  "CamelPhat: ['deep tech house', 'disco house', 'edm', 'house', 'pop dance', 'progressive house', 'tropical house']",
#  'LOWES: []',
#  'Cherry Tomato: []',
#  "Khruangbin: ['neo-psychedelic']",
#  'Memphis LK: []',
#  "Ólafur Arnalds: ['bow pop', 'compositional ambient', 'icelandic classical', 'neo-classical', 'neoclassical darkwave']",
#  "KOAN Sound: ['complextro', 'edm', 'electro house', 'filthstep', 'glitch']",
#  "Typhoon: ['indie pop', 'portland indie', 'stomp and holler']",
#  'Cherry Coke: []',
#  "Lady Lamb: ['indie pop', 'indie rock', 'indie singer-songwriter', 'maine indie']",
#  "Denzel Curry: ['dark trap', 'drill', 'hip hop', 'miami hip hop', 'rap', 'trap', 'underground hip hop']",
#  "Kenny Beats: ['trap', 'underground hip hop']",
#  'MAXINE: []',
#  "Stick Figure: ['reggae fusion']",
#  'Stablemate: []',
#  'Lucy Sugerman: []',
#  "Ariana Grande: ['pop', 'post-teen pop']",
#  "ONR: ['scottish indie']",
#  'Sarah Barthel: []',
#  "Phantogram: ['alternative dance', 'chillwave', 'dream pop', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'shimmer pop', 'vapor soul']",
#  "Lykke Li: ['art pop', 'dance pop', 'electropop', 'pop', 'swedish electropop', 'swedish indie pop', 'swedish pop']",
#  "Goth Babe: ['indie garage rock', 'indie pop', 'indie rock', 'modern rock', 'vapor soul']"]

# %%
genres = []
for artist in artists:
    genre = artist[artist.find("[")+1:artist.find("]")]
    genres.append(genre)
genres


# I like the result of the first for loop more.
# second_list =[]
# for artist in artists:
#     genre = re.findall(r'\[.*?\]', artist)
#     second_list.append(genre)
# second_list
# Out:
# ['',
#  '',
#  '',
#  "'alternative rock', 'garage rock', 'garage rock revival', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'rock', 'supergroup'",
#  "'vapor twitch'",
#  "'australian alternative pop', 'australian pop'",
#  "'australian house', 'bass house', 'fidget house'",
#  '',
#  "'chillwave', 'downtempo', 'electronica', 'indietronica', 'intelligent dance music'",
#  "'downtempo bass'",
#  "'indie pop'",
#  "'electropop', 'modern alternative rock', 'modern rock', 'pixie', 'pop', 'pop emo', 'pop punk', 'rock'",
#  '',
#  "'australian pop'",
#  "'uk pop'",
#  '',
#  "'uk alternative pop'",
#  "'indie soul', 'uk alternative pop'",
#  "'dance pop', 'hip pop', 'pop', 'pop dance', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary'",
#  "'christian hip hop', 'houston rap'",
#  '',
#  "'bedroom pop', 'boston indie'",
#  "'jawaiian', 'reggae rock'",
#  "'reggae fusion', 'reggae rock'",
#  "'aussietronica'",
#  "'aussietronica'",
#  '',
#  "'alternative hip hop', 'canadian modern jazz', 'escape room', 'funk', 'hip hop', 'indie soul'",
#  "'sydney indie'",
#  "'la pop', 'pop'",
#  "'australian garage punk', 'australian psych', 'neo-psychedelic'",
#  "'big beat', 'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop'",
#  "'brisbane indie', 'indie anthem-folk'",
#  "'danish indie pop'",
#  "'art pop', 'baroque pop', 'chamber pop', 'chicago indie', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'melancholia', 'stomp and holler'",
#  '',
#  "'pop punk', 'punk', 'socal pop punk'",
#  "'edm', 'electropop', 'indie poptimism', 'pop', 'pop dance', 'pop edm', 'tropical house'",
#  "'deep tropical house', 'pop edm', 'tropical house'",
#  "'deep new americana', 'funk', 'indie folk', 'retro soul'",
#  "'big room', 'edm', 'electro house', 'electropop', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'tropical house'",
#  '',
#  "'australian alternative pop'",
#  "'australian garage punk', 'australian indie rock'",
#  "'bedroom pop', 'modern rock', 'oakland indie', 'pop'",
#  '',
#  "'alternative dance', 'dance-punk', 'electropop', 'escape room', 'new rave'",
#  "'alternative r&b', 'edm', 'electropop', 'indie electropop', 'indie soul', 'tropical house', 'vapor soul', 'vapor twitch'",
#  "'alternative r&b', 'gauze pop', 'indie r&b', 'indie soul', 'uk contemporary r&b'",
#  '',
#  "'instrumental math rock', 'southeast asian post-rock', 'taiwan indie'",
#  '',
#  "'conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap'",
#  "'australian indie rock', 'brisbane indie'",
#  "'australian hip hop', 'australian trap'",
#  "'australian trap'",
#  '',
#  "'deep tropical house', 'electropop', 'pop dance', 'pop edm'",
#  '',
#  '',
#  '',
#  '',
#  "'australian hip hop'",
#  '',
#  '',
#  "'british alternative rock', 'modern alternative rock', 'modern rock', 'pixie', 'pop emo'",
#  "'boston rock', 'neo mellow', 'pop rock'",
#  "'gauze pop', 'progressive house', 'tropical house'",
#  "'art pop', 'chillwave', 'electropop', 'metropopolis', 'shimmer pop'",
#  "'kent indie'",
#  "'vapor pop'",
#  "'australian indie folk', 'indie anthem-folk'",
#  "'uk house'",
#  "'contemporary jazz', 'funk rock', 'jazz funk', 'jazz fusion', 'progressive jazz fusion'",
#  "'alternative r&b', 'edm', 'indie soul', 'pop', 'uk dance', 'vapor soul'",
#  "'bedroom pop', 'boston indie'",
#  "'australian hip hop', 'australian indie', 'australian pop', 'australian trap'",
#  "'australian indie', 'indie dream pop'",
#  "'bubblegrunge', 'indie pop', 'indie rock', 'minneapolis indie'",
#  "'edm', 'progressive house', 'progressive trance', 'trance', 'uplifting trance'",
#  '',
#  "'electropop', 'indie poptimism', 'modern rock', 'pop'",
#  "'chicago rap', 'conscious hip hop', 'hip hop', 'political hip hop', 'pop rap', 'rap', 'southern hip hop'",
#  "'indie electropop'",
#  '',
#  "'aussietronica'",
#  "'adelaide indie', 'australian garage punk', 'garage psych'",
#  "'filter house', 'indie soul'",
#  "'christian indie', 'indiecoustica', 'ok indie'",
#  "'alternative dance', 'electrofox', 'indie poptimism', 'metropopolis', 'northamptonshire indie', 'shimmer pop'",
#  "'dfw rap', 'melodic rap', 'rap'",
#  "'australian indie', 'australian pop', 'fremantle indie', 'metropopolis', 'perth indie'",
#  "'ambeat'",
#  "'ambeat'",
#  "'ambeat', 'chillhop'",
#  "'underground rap'",
#  "'ambeat'",
#  '',
#  "'focus beats'",
#  "'aussie emo', 'australian post-hardcore', 'newcastle nsw indie'",
#  "'electropop', 'etherpop', 'indie folk', 'indie pop', 'indie rock'",
#  "'australian indie', 'australian pop'",
#  "'kawaii future bass', 'lo-fi beats'",
#  '',
#  '',
#  "'electropop', 'indie pop', 'indie poptimism', 'indietronica', 'modern dream pop', 'vapor soul'",
#  "'alternative dance', 'alternative rock', 'dance-punk', 'indie rock', 'modern rock', 'new rave', 'rock'",
#  "'australian indie', 'australian pop'",
#  '',
#  "'chillhop', 'downtempo', 'japanese chillhop', 'jazz rap'",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "'hawaiian hip hop'",
#  "'bass trap', 'modern alternative rock', 'traprun'",
#  '',
#  "'australian garage punk', 'australian indie', 'australian indie rock', 'fremantle indie', 'perth indie'",
#  "'australian psych', 'neo-psychedelic'",
#  "'canadian indie', 'kelowna bc indie', 'vancouver indie'",
#  "'electropop', 'pop'",
#  "'australian indie rock'",
#  '',
#  "'australian reggae fusion', 'australian ska', 'ska jazz'",
#  "'art pop', 'brooklyn indie', 'chamber pop', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'small room', 'stomp and holler'",
#  "'electronica', 'french indie pop', 'french indietronica', 'new french touch'",
#  '',
#  "'canadian indie', 'indie rock', 'vancouver indie'",
#  "'indie anthem-folk', 'vapor soul'",
#  "'adelaide indie'",
#  "'aussie drill', 'australian trap'",
#  "'aussie drill'",
#  "'american post-rock', 'compositional ambient', 'post-rock'",
#  "'art pop', 'freak folk', 'indie pop', 'indie rock', 'one-person band'",
#  "'nz pop'",
#  "'indonesian edm'",
#  '',
#  "'indonesian indie'",
#  "'new french touch'",
#  '',
#  "'australian alternative pop'",
#  '',
#  "'minneapolis indie'",
#  "'deep new americana', 'indiecoustica', 'stomp and holler'",
#  "'alternative roots rock', 'garage rock', 'modern alternative rock', 'modern blues rock', 'modern hard rock', 'modern rock', 'punk blues', 'rock'",
#  "'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop'",
#  "'electronica', 'future garage', 'indie soul'",
#  "'alternative dance', 'art pop', 'dance pop', 'electronica', 'experimental pop', 'experimental vocal', 'icelandic experimental', 'icelandic pop', 'metropopolis', 'permanent wave', 'trip hop'",
#  "'bass music', 'chillwave', 'electronica', 'microhouse', 'ninja', 'wonky'",
#  "'afrofuturism', 'alternative r&b', 'art pop', 'escape room', 'indie soul', 'la pop'",
#  "'oc indie'",
#  "'alternative r&b', 'indie r&b'",
#  '',
#  '',
#  '',
#  "'hip hop', 'pittsburgh rap', 'rap'",
#  "'art pop', 'chillwave', 'electronica', 'indie soul'",
#  "'dancehall', 'lovers rock', 'modern reggae', 'reggae fusion', 'roots reggae'",
#  '',
#  "'indie dream pop', 'indie shoegaze', 'metropopolis'",
#  "'tassie indie'",
#  "'alternative metal', 'alternative rock', 'blues rock', 'modern rock', 'nu metal', 'palm desert scene', 'rock', 'stoner metal', 'stoner rock'",
#  "'alternative dance', 'dance-punk', 'indie pop', 'indie rock', 'modern rock', 'new rave', 'rock', 'rock independant francais'",
#  "'auckland indie', 'electropop', 'etherpop', 'indie electropop', 'indie pop', 'indie poptimism', 'indietronica', 'metropopolis', 'nz pop', 'pop', 'shimmer pop', 'tropical house', 'vapor soul'",
#  "'german hip hop', 'german pop', 'pop rap'",
#  "'german pop', 'german r&b'",
#  "'indie cafe pop', 'indiecoustica'",
#  "'alternative r&b', 'chill r&b', 'indie r&b', 'nyc pop', 'pop', 'vapor soul'",
#  "'indie anthem-folk', 'indie folk'",
#  "'indie pop', 'indie poptimism', 'indie rock', 'minneapolis indie', 'modern alternative rock', 'modern rock'",
#  "'electropop', 'indie electropop', 'indie pop', 'indie poptimism', 'indie soul', 'vapor soul'",
#  '',
#  "'modern ska punk'",
#  '',
#  "'adelaide indie'",
#  "'australian indie', 'australian pop'",
#  "'chillstep', 'vapor twitch'",
#  "'nz pop', 'pop'",
#  "'australian garage punk', 'australian indie', 'australian pop'",
#  "'german indie', 'german pop', 'german rock'",
#  "'alternative r&b', 'bedroom pop', 'indie cafe pop', 'indie pop', 'pop'",
#  "'alternative r&b', 'escape room', 'indie r&b', 'indie soul', 'neo soul'",
#  "'atl hip hop', 'hip hop', 'pop rap', 'rap'",
#  "'alternative hip hop', 'dmv rap', 'hip hop', 'sudanese pop'",
#  "'alternative dance', 'dance-punk', 'electronica', 'new rave'",
#  '',
#  "'australian indie rock'",
#  '',
#  "'indie folk', 'indie rock', 'modern alternative rock', 'modern rock', 'stomp and holler'",
#  "'seattle indie'",
#  '',
#  "'dance pop', 'electropop', 'escape room', 'pop', 'post-teen pop', 'trap queen'",
#  "'nashville indie'",
#  "'reggae rock'",
#  "'jam band', 'jamtronica', 'livetronica'",
#  "'metropopolis', 'nottingham indie'",
#  "'art pop', 'canadian electropop', 'chillwave', 'edmonton indie', 'electropop', 'grave wave', 'indietronica', 'metropopolis', 'shimmer pop', 'vapor soul'",
#  "'downtempo bass'",
#  "'indie soul', 'jazz pop'",
#  "'british soul', 'uk alternative pop'",
#  '',
#  "'australian electropop', 'edm', 'indietronica'",
#  '',
#  "'downtempo', 'electronica', 'nu jazz', 'trip hop'",
#  "'birmingham hip hop'",
#  "'vienna indie'",
#  '',
#  "'baroque pop', 'brooklyn indie'",
#  "'indie folk', 'indie pop', 'metropopolis', 'shimmer pop', 'stomp and holler', 'stomp and whittle'",
#  "'jacksonville indie', 'modern rock'",
#  "'freak folk', 'philly indie', 'stomp and holler'",
#  "'alternative pop rock', 'modern alternative rock', 'modern rock', 'rock'",
#  '',
#  '',
#  "'underground hip hop'",
#  "'french indie pop', 'french indietronica', 'french synthpop', 'indie soul', 'new french touch'",
#  '',
#  "'danish jazz', 'danish modern jazz'",
#  '',
#  "'electra'",
#  "'reggae fusion', 'reggae rock'",
#  "'electropop', 'metropopolis', 'vapor pop'",
#  '',
#  "'new french touch'",
#  "'deep underground hip hop', 'indie pop rap', 'pop rap'",
#  "'chillhop', 'lo-fi beats'",
#  "'birmingham indie', 'english indie rock', 'modern alternative rock', 'modern rock'",
#  "'pop rap'",
#  "'alternative hip hop', 'big beat', 'electronica', 'hip hop', 'jazztronica', 'ninja', 'nu jazz', 'turntablism'",
#  "'indie pop', 'indie rock'",
#  "'australian indie', 'australian pop', 'indie soul'",
#  "'cyberpunk', 'synthwave'",
#  "'popwave', 'spacewave', 'synthwave'",
#  "'australian alternative pop', 'australian indie', 'shimmer pop'",
#  '',
#  "'alternative dance', 'big beat', 'downtempo', 'electronica', 'electropop', 'trip hop'",
#  "'indie pop', 'nyc pop'",
#  "'comic', 'conscious hip hop'",
#  "'australian dance'",
#  "'australian garage punk', 'brisbane indie'",
#  '',
#  "'escape room', 'indie soul', 'trap queen', 'uk alternative hip hop'",
#  "'chicago soul', 'classic soul', 'funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'southern soul'",
#  "'cali rap', 'modern alternative rock'",
#  "'bounce', 'escape room', 'lgbtq+ hip hop', 'new orleans rap', 'trap queen'",
#  "'dance pop', 'escape room', 'minnesota hip hop', 'pop', 'pop dance', 'pop rap', 'trap queen'",
#  "'retro soul'",
#  "'french indie pop', 'french indietronica', 'new french touch'",
#  "'nova mpb'",
#  '',
#  '',
#  "'spanish modern rock'",
#  "'alternative dance', 'indie soul', 'new rave', 'nu disco'",
#  "'la pop'",
#  "'edm', 'electropop', 'pop dance', 'pop edm', 'tropical house'",
#  "'dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop'",
#  "'british jazz', 'compositional ambient', 'contemporary jazz', 'electronica', 'jazz quartet', 'new tribe', 'nu jazz'",
#  "'abstract hip hop', 'comic', 'modern rock', 'pop rap'",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "'alternative r&b', 'aussietronica', 'electropop', 'indie electropop', 'indie soul', 'vapor soul'",
#  "'alternative dance', 'vapor soul'",
#  "'australian indie'",
#  "'australian trap'",
#  "'rock independant francais'",
#  "'art pop', 'bay area indie', 'chillwave', 'indie folk', 'indie pop', 'indie rock', 'oakland indie', 'small room'",
#  "'art pop', 'bubblegrunge', 'eugene indie', 'indie pop', 'indie rock', 'philly indie'",
#  "'australian indie', 'australian pop'",
#  "'reggae fusion', 'reggae rock'",
#  "'austindie', 'pop soul'",
#  "'st petersburg fl indie'",
#  '',
#  "'gangster rap', 'hyphy', 'west coast rap', 'west coast trap'",
#  '',
#  "'arabic jazz', 'french jazz', 'jazz trumpet'",
#  "'aussietronica', 'edm', 'gauze pop', 'house', 'indie soul', 'pop dance', 'tropical house'",
#  "'candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'pop dance', 'swedish electropop', 'swedish synthpop'",
#  "'nz pop'",
#  "'big room', 'edm', 'electro house', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'progressive trance', 'trance', 'tropical house', 'uplifting trance'",
#  '',
#  "'korean dream pop'",
#  '',
#  "'indie pop', 'indie poptimism', 'indie rock', 'la indie', 'modern alternative rock', 'modern rock', 'pop rock'",
#  "'indie cafe pop', 'indie pop', 'pop'",
#  "'instrumental rock'",
#  "'australian indie', 'electropop', 'vapor soul'",
#  "'electronica', 'hamburg electronic', 'microhouse', 'minimal techno', 'new french touch', 'organic electronic', 'pop ambient'",
#  '',
#  "'australian hip hop'",
#  "'candy pop', 'emo', 'pixie', 'pop emo', 'pop punk'",
#  "'disco house', 'filter house', 'vocal house'",
#  "'classical piano', 'turkish classical performance', 'turkish jazz'",
#  "'taiwan classical performance'",
#  "'australian electropop'",
#  "'vapor pop'",
#  "'bedroom pop', 'bubblegrunge', 'indie pop'",
#  "'australian reggae fusion'",
#  "'indie jazz', 'indie soul'",
#  "'alternative dance', 'canadian indie', 'canadian rock', 'dance-punk', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'neo-synthpop', 'new rave', 'rock', 'shimmer pop'",
#  '',
#  '',
#  '',
#  "'chillwave', 'indie jazz', 'wonky'",
#  "'australian indie rock'",
#  '',
#  '',
#  '',
#  "'alternative hip hop', 'atl hip hop', 'conscious hip hop', 'dirty south rap', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap'",
#  "'alternative hip hop', 'bronx hip hop', 'conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'old school hip hop', 'political hip hop', 'rap', 'turntablism'",
#  "'alternative hip hop', 'chicago rap', 'conscious hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'neo soul', 'political hip hop', 'rap', 'southern hip hop'",
#  "'ambeat', 'jazz rap', 'underground rap'",
#  '',
#  '',
#  '',
#  "'electropop', 'indie electropop', 'indie poptimism'",
#  "'art pop', 'bubblegrunge', 'indie folk', 'indie pop', 'indie rock'",
#  '',
#  "'alternative hip hop', 'escape room', 'experimental hip hop', 'industrial hip hop'",
#  "'art pop', 'chamber psych'",
#  "'chamber psych', 'fourth world', 'indie folk', 'indie jazz', 'uk contemporary jazz'",
#  "'afrobeat', 'afropop', 'desert blues', 'malian blues', 'mande pop', 'world'",
#  "'blues', 'blues rock', 'country blues', 'country rock', 'folk', 'folk rock', 'mellow gold', 'piedmont blues', 'roots rock', 'singer-songwriter', 'traditional folk'",
#  "'canadian indie', 'indie folk', 'indie pop', 'new americana', 'stomp and holler'",
#  "'german house'",
#  '',
#  "'edm', 'electropop', 'pop', 'pop dance', 'tropical house'",
#  "'electropop', 'indie pop', 'pop'",
#  "'alternative dance', 'auckland indie', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'kiwi rock', 'metropopolis', 'modern rock', 'shimmer pop'",
#  "'dixieland', 'jazz clarinet', 'new orleans jazz'",
#  "'irish neo-traditional'",
#  "'brisbane indie'",
#  "'australian garage punk'",
#  "'downtempo', 'electronica', 'livetronica', 'trip hop'",
#  '',
#  '',
#  "'australian hip hop'",
#  "'alternative dance', 'electronica'",
#  "'alternative country', 'queer country'",
#  '',
#  "'chanson', 'french indie pop', 'french indietronica', 'french rock', 'nouvelle chanson francaise'",
#  "'belgian pop', 'variete francaise'",
#  "'neo-classical'",
#  "'electronica', 'hamburg electronic', 'microhouse', 'minimal techno'",
#  "'asian american hip hop', 'battle rap', 'k-rap'",
#  '',
#  '',
#  "'deep tech house', 'disco house', 'edm', 'house', 'pop dance', 'progressive house', 'tropical house'",
#  '',
#  '',
#  "'neo-psychedelic'",
#  '',
#  "'bow pop', 'compositional ambient', 'icelandic classical', 'neo-classical', 'neoclassical darkwave'",
#  "'complextro', 'edm', 'electro house', 'filthstep', 'glitch'",
#  "'indie pop', 'portland indie', 'stomp and holler'",
#  '',
#  "'indie pop', 'indie rock', 'indie singer-songwriter', 'maine indie'",
#  "'dark trap', 'drill', 'hip hop', 'miami hip hop', 'rap', 'trap', 'underground hip hop'",
#  "'trap', 'underground hip hop'",
#  '',
#  "'reggae fusion'",
#  '',
#  '',
#  "'pop', 'post-teen pop'",
#  "'scottish indie'",
#  '',
#  "'alternative dance', 'chillwave', 'dream pop', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'shimmer pop', 'vapor soul'",
#  "'art pop', 'dance pop', 'electropop', 'pop', 'swedish electropop', 'swedish indie pop', 'swedish pop'",
#  "'indie garage rock', 'indie pop', 'indie rock', 'modern rock', 'vapor soul'"]

# %%
len(genres)
# Out:
# 374

# %% [markdown]
# I had to iterate over this multiple times before it truly removed all the items in the list that were empty....why didn't it fully work the first time???

# %%
for genre in genres:
    if genre == '':
        genres.remove(genre)

# %%
genres
# Out:
# ["'alternative rock', 'garage rock', 'garage rock revival', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'rock', 'supergroup'",
#  "'vapor twitch'",
#  "'australian alternative pop', 'australian pop'",
#  "'australian house', 'bass house', 'fidget house'",
#  "'chillwave', 'downtempo', 'electronica', 'indietronica', 'intelligent dance music'",
#  "'downtempo bass'",
#  "'indie pop'",
#  "'electropop', 'modern alternative rock', 'modern rock', 'pixie', 'pop', 'pop emo', 'pop punk', 'rock'",
#  "'australian pop'",
#  "'uk pop'",
#  "'uk alternative pop'",
#  "'indie soul', 'uk alternative pop'",
#  "'dance pop', 'hip pop', 'pop', 'pop dance', 'pop rap', 'post-teen pop', 'r&b', 'urban contemporary'",
#  "'christian hip hop', 'houston rap'",
#  "'bedroom pop', 'boston indie'",
#  "'jawaiian', 'reggae rock'",
#  "'reggae fusion', 'reggae rock'",
#  "'aussietronica'",
#  "'aussietronica'",
#  "'alternative hip hop', 'canadian modern jazz', 'escape room', 'funk', 'hip hop', 'indie soul'",
#  "'sydney indie'",
#  "'la pop', 'pop'",
#  "'australian garage punk', 'australian psych', 'neo-psychedelic'",
#  "'big beat', 'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop'",
#  "'brisbane indie', 'indie anthem-folk'",
#  "'danish indie pop'",
#  "'art pop', 'baroque pop', 'chamber pop', 'chicago indie', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'melancholia', 'stomp and holler'",
#  "'pop punk', 'punk', 'socal pop punk'",
#  "'edm', 'electropop', 'indie poptimism', 'pop', 'pop dance', 'pop edm', 'tropical house'",
#  "'deep tropical house', 'pop edm', 'tropical house'",
#  "'deep new americana', 'funk', 'indie folk', 'retro soul'",
#  "'big room', 'edm', 'electro house', 'electropop', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'tropical house'",
#  "'australian alternative pop'",
#  "'australian garage punk', 'australian indie rock'",
#  "'bedroom pop', 'modern rock', 'oakland indie', 'pop'",
#  "'alternative dance', 'dance-punk', 'electropop', 'escape room', 'new rave'",
#  "'alternative r&b', 'edm', 'electropop', 'indie electropop', 'indie soul', 'tropical house', 'vapor soul', 'vapor twitch'",
#  "'alternative r&b', 'gauze pop', 'indie r&b', 'indie soul', 'uk contemporary r&b'",
#  "'instrumental math rock', 'southeast asian post-rock', 'taiwan indie'",
#  "'conscious hip hop', 'dmv rap', 'hip hop', 'pop rap', 'rap'",
#  "'australian indie rock', 'brisbane indie'",
#  "'australian hip hop', 'australian trap'",
#  "'australian trap'",
#  "'deep tropical house', 'electropop', 'pop dance', 'pop edm'",
#  "'australian hip hop'",
#  "'british alternative rock', 'modern alternative rock', 'modern rock', 'pixie', 'pop emo'",
#  "'boston rock', 'neo mellow', 'pop rock'",
#  "'gauze pop', 'progressive house', 'tropical house'",
#  "'art pop', 'chillwave', 'electropop', 'metropopolis', 'shimmer pop'",
#  "'kent indie'",
#  "'vapor pop'",
#  "'australian indie folk', 'indie anthem-folk'",
#  "'uk house'",
#  "'contemporary jazz', 'funk rock', 'jazz funk', 'jazz fusion', 'progressive jazz fusion'",
#  "'alternative r&b', 'edm', 'indie soul', 'pop', 'uk dance', 'vapor soul'",
#  "'bedroom pop', 'boston indie'",
#  "'australian hip hop', 'australian indie', 'australian pop', 'australian trap'",
#  "'australian indie', 'indie dream pop'",
#  "'bubblegrunge', 'indie pop', 'indie rock', 'minneapolis indie'",
#  "'edm', 'progressive house', 'progressive trance', 'trance', 'uplifting trance'",
#  "'electropop', 'indie poptimism', 'modern rock', 'pop'",
#  "'chicago rap', 'conscious hip hop', 'hip hop', 'political hip hop', 'pop rap', 'rap', 'southern hip hop'",
#  "'indie electropop'",
#  "'aussietronica'",
#  "'adelaide indie', 'australian garage punk', 'garage psych'",
#  "'filter house', 'indie soul'",
#  "'christian indie', 'indiecoustica', 'ok indie'",
#  "'alternative dance', 'electrofox', 'indie poptimism', 'metropopolis', 'northamptonshire indie', 'shimmer pop'",
#  "'dfw rap', 'melodic rap', 'rap'",
#  "'australian indie', 'australian pop', 'fremantle indie', 'metropopolis', 'perth indie'",
#  "'ambeat'",
#  "'ambeat'",
#  "'ambeat', 'chillhop'",
#  "'underground rap'",
#  "'ambeat'",
#  "'focus beats'",
#  "'aussie emo', 'australian post-hardcore', 'newcastle nsw indie'",
#  "'electropop', 'etherpop', 'indie folk', 'indie pop', 'indie rock'",
#  "'australian indie', 'australian pop'",
#  "'kawaii future bass', 'lo-fi beats'",
#  "'electropop', 'indie pop', 'indie poptimism', 'indietronica', 'modern dream pop', 'vapor soul'",
#  "'alternative dance', 'alternative rock', 'dance-punk', 'indie rock', 'modern rock', 'new rave', 'rock'",
#  "'australian indie', 'australian pop'",
#  "'chillhop', 'downtempo', 'japanese chillhop', 'jazz rap'",
#  "'hawaiian hip hop'",
#  "'bass trap', 'modern alternative rock', 'traprun'",
#  "'australian garage punk', 'australian indie', 'australian indie rock', 'fremantle indie', 'perth indie'",
#  "'australian psych', 'neo-psychedelic'",
#  "'canadian indie', 'kelowna bc indie', 'vancouver indie'",
#  "'electropop', 'pop'",
#  "'australian indie rock'",
#  "'australian reggae fusion', 'australian ska', 'ska jazz'",
#  "'art pop', 'brooklyn indie', 'chamber pop', 'freak folk', 'indie folk', 'indie pop', 'indie rock', 'small room', 'stomp and holler'",
#  "'electronica', 'french indie pop', 'french indietronica', 'new french touch'",
#  "'canadian indie', 'indie rock', 'vancouver indie'",
#  "'indie anthem-folk', 'vapor soul'",
#  "'adelaide indie'",
#  "'aussie drill', 'australian trap'",
#  "'aussie drill'",
#  "'american post-rock', 'compositional ambient', 'post-rock'",
#  "'art pop', 'freak folk', 'indie pop', 'indie rock', 'one-person band'",
#  "'nz pop'",
#  "'indonesian edm'",
#  "'indonesian indie'",
#  "'new french touch'",
#  "'australian alternative pop'",
#  "'minneapolis indie'",
#  "'deep new americana', 'indiecoustica', 'stomp and holler'",
#  "'alternative roots rock', 'garage rock', 'modern alternative rock', 'modern blues rock', 'modern hard rock', 'modern rock', 'punk blues', 'rock'",
#  "'downtempo', 'electronica', 'jazztronica', 'ninja', 'nu jazz', 'trip hop'",
#  "'electronica', 'future garage', 'indie soul'",
#  "'alternative dance', 'art pop', 'dance pop', 'electronica', 'experimental pop', 'experimental vocal', 'icelandic experimental', 'icelandic pop', 'metropopolis', 'permanent wave', 'trip hop'",
#  "'bass music', 'chillwave', 'electronica', 'microhouse', 'ninja', 'wonky'",
#  "'afrofuturism', 'alternative r&b', 'art pop', 'escape room', 'indie soul', 'la pop'",
#  "'oc indie'",
#  "'alternative r&b', 'indie r&b'",
#  "'hip hop', 'pittsburgh rap', 'rap'",
#  "'art pop', 'chillwave', 'electronica', 'indie soul'",
#  "'dancehall', 'lovers rock', 'modern reggae', 'reggae fusion', 'roots reggae'",
#  "'indie dream pop', 'indie shoegaze', 'metropopolis'",
#  "'tassie indie'",
#  "'alternative metal', 'alternative rock', 'blues rock', 'modern rock', 'nu metal', 'palm desert scene', 'rock', 'stoner metal', 'stoner rock'",
#  "'alternative dance', 'dance-punk', 'indie pop', 'indie rock', 'modern rock', 'new rave', 'rock', 'rock independant francais'",
#  "'auckland indie', 'electropop', 'etherpop', 'indie electropop', 'indie pop', 'indie poptimism', 'indietronica', 'metropopolis', 'nz pop', 'pop', 'shimmer pop', 'tropical house', 'vapor soul'",
#  "'german hip hop', 'german pop', 'pop rap'",
#  "'german pop', 'german r&b'",
#  "'indie cafe pop', 'indiecoustica'",
#  "'alternative r&b', 'chill r&b', 'indie r&b', 'nyc pop', 'pop', 'vapor soul'",
#  "'indie anthem-folk', 'indie folk'",
#  "'indie pop', 'indie poptimism', 'indie rock', 'minneapolis indie', 'modern alternative rock', 'modern rock'",
#  "'electropop', 'indie electropop', 'indie pop', 'indie poptimism', 'indie soul', 'vapor soul'",
#  "'modern ska punk'",
#  "'adelaide indie'",
#  "'australian indie', 'australian pop'",
#  "'chillstep', 'vapor twitch'",
#  "'nz pop', 'pop'",
#  "'australian garage punk', 'australian indie', 'australian pop'",
#  "'german indie', 'german pop', 'german rock'",
#  "'alternative r&b', 'bedroom pop', 'indie cafe pop', 'indie pop', 'pop'",
#  "'alternative r&b', 'escape room', 'indie r&b', 'indie soul', 'neo soul'",
#  "'atl hip hop', 'hip hop', 'pop rap', 'rap'",
#  "'alternative hip hop', 'dmv rap', 'hip hop', 'sudanese pop'",
#  "'alternative dance', 'dance-punk', 'electronica', 'new rave'",
#  "'australian indie rock'",
#  "'indie folk', 'indie rock', 'modern alternative rock', 'modern rock', 'stomp and holler'",
#  "'seattle indie'",
#  "'dance pop', 'electropop', 'escape room', 'pop', 'post-teen pop', 'trap queen'",
#  "'nashville indie'",
#  "'reggae rock'",
#  "'jam band', 'jamtronica', 'livetronica'",
#  "'metropopolis', 'nottingham indie'",
#  "'art pop', 'canadian electropop', 'chillwave', 'edmonton indie', 'electropop', 'grave wave', 'indietronica', 'metropopolis', 'shimmer pop', 'vapor soul'",
#  "'downtempo bass'",
#  "'indie soul', 'jazz pop'",
#  "'british soul', 'uk alternative pop'",
#  "'australian electropop', 'edm', 'indietronica'",
#  "'downtempo', 'electronica', 'nu jazz', 'trip hop'",
#  "'birmingham hip hop'",
#  "'vienna indie'",
#  "'baroque pop', 'brooklyn indie'",
#  "'indie folk', 'indie pop', 'metropopolis', 'shimmer pop', 'stomp and holler', 'stomp and whittle'",
#  "'jacksonville indie', 'modern rock'",
#  "'freak folk', 'philly indie', 'stomp and holler'",
#  "'alternative pop rock', 'modern alternative rock', 'modern rock', 'rock'",
#  "'underground hip hop'",
#  "'french indie pop', 'french indietronica', 'french synthpop', 'indie soul', 'new french touch'",
#  "'danish jazz', 'danish modern jazz'",
#  "'electra'",
#  "'reggae fusion', 'reggae rock'",
#  "'electropop', 'metropopolis', 'vapor pop'",
#  "'new french touch'",
#  "'deep underground hip hop', 'indie pop rap', 'pop rap'",
#  "'chillhop', 'lo-fi beats'",
#  "'birmingham indie', 'english indie rock', 'modern alternative rock', 'modern rock'",
#  "'pop rap'",
#  "'alternative hip hop', 'big beat', 'electronica', 'hip hop', 'jazztronica', 'ninja', 'nu jazz', 'turntablism'",
#  "'indie pop', 'indie rock'",
#  "'australian indie', 'australian pop', 'indie soul'",
#  "'cyberpunk', 'synthwave'",
#  "'popwave', 'spacewave', 'synthwave'",
#  "'australian alternative pop', 'australian indie', 'shimmer pop'",
#  "'alternative dance', 'big beat', 'downtempo', 'electronica', 'electropop', 'trip hop'",
#  "'indie pop', 'nyc pop'",
#  "'comic', 'conscious hip hop'",
#  "'australian dance'",
#  "'australian garage punk', 'brisbane indie'",
#  "'escape room', 'indie soul', 'trap queen', 'uk alternative hip hop'",
#  "'chicago soul', 'classic soul', 'funk', 'memphis soul', 'motown', 'quiet storm', 'soul', 'southern soul'",
#  "'cali rap', 'modern alternative rock'",
#  "'bounce', 'escape room', 'lgbtq+ hip hop', 'new orleans rap', 'trap queen'",
#  "'dance pop', 'escape room', 'minnesota hip hop', 'pop', 'pop dance', 'pop rap', 'trap queen'",
#  "'retro soul'",
#  "'french indie pop', 'french indietronica', 'new french touch'",
#  "'nova mpb'",
#  "'spanish modern rock'",
#  "'alternative dance', 'indie soul', 'new rave', 'nu disco'",
#  "'la pop'",
#  "'edm', 'electropop', 'pop dance', 'pop edm', 'tropical house'",
#  "'dance pop', 'electropop', 'pop', 'post-teen pop', 'viral pop'",
#  "'british jazz', 'compositional ambient', 'contemporary jazz', 'electronica', 'jazz quartet', 'new tribe', 'nu jazz'",
#  "'abstract hip hop', 'comic', 'modern rock', 'pop rap'",
#  "'alternative r&b', 'aussietronica', 'electropop', 'indie electropop', 'indie soul', 'vapor soul'",
#  "'alternative dance', 'vapor soul'",
#  "'australian indie'",
#  "'australian trap'",
#  "'rock independant francais'",
#  "'art pop', 'bay area indie', 'chillwave', 'indie folk', 'indie pop', 'indie rock', 'oakland indie', 'small room'",
#  "'art pop', 'bubblegrunge', 'eugene indie', 'indie pop', 'indie rock', 'philly indie'",
#  "'australian indie', 'australian pop'",
#  "'reggae fusion', 'reggae rock'",
#  "'austindie', 'pop soul'",
#  "'st petersburg fl indie'",
#  "'gangster rap', 'hyphy', 'west coast rap', 'west coast trap'",
#  "'arabic jazz', 'french jazz', 'jazz trumpet'",
#  "'aussietronica', 'edm', 'gauze pop', 'house', 'indie soul', 'pop dance', 'tropical house'",
#  "'candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'pop dance', 'swedish electropop', 'swedish synthpop'",
#  "'nz pop'",
#  "'big room', 'edm', 'electro house', 'pop dance', 'pop edm', 'progressive electro house', 'progressive house', 'progressive trance', 'trance', 'tropical house', 'uplifting trance'",
#  "'korean dream pop'",
#  "'indie pop', 'indie poptimism', 'indie rock', 'la indie', 'modern alternative rock', 'modern rock', 'pop rock'",
#  "'indie cafe pop', 'indie pop', 'pop'",
#  "'instrumental rock'",
#  "'australian indie', 'electropop', 'vapor soul'",
#  "'electronica', 'hamburg electronic', 'microhouse', 'minimal techno', 'new french touch', 'organic electronic', 'pop ambient'",
#  "'australian hip hop'",
#  "'candy pop', 'emo', 'pixie', 'pop emo', 'pop punk'",
#  "'disco house', 'filter house', 'vocal house'",
#  "'classical piano', 'turkish classical performance', 'turkish jazz'",
#  "'taiwan classical performance'",
#  "'australian electropop'",
#  "'vapor pop'",
#  "'bedroom pop', 'bubblegrunge', 'indie pop'",
#  "'australian reggae fusion'",
#  "'indie jazz', 'indie soul'",
#  "'alternative dance', 'canadian indie', 'canadian rock', 'dance-punk', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'neo-synthpop', 'new rave', 'rock', 'shimmer pop'",
#  "'chillwave', 'indie jazz', 'wonky'",
#  "'australian indie rock'",
#  "'alternative hip hop', 'atl hip hop', 'conscious hip hop', 'dirty south rap', 'gangster rap', 'hardcore hip hop', 'hip hop', 'rap', 'southern hip hop', 'trap'",
#  "'alternative hip hop', 'bronx hip hop', 'conscious hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'old school hip hop', 'political hip hop', 'rap', 'turntablism'",
#  "'alternative hip hop', 'chicago rap', 'conscious hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'neo soul', 'political hip hop', 'rap', 'southern hip hop'",
#  "'ambeat', 'jazz rap', 'underground rap'",
#  "'electropop', 'indie electropop', 'indie poptimism'",
#  "'art pop', 'bubblegrunge', 'indie folk', 'indie pop', 'indie rock'",
#  "'alternative hip hop', 'escape room', 'experimental hip hop', 'industrial hip hop'",
#  "'art pop', 'chamber psych'",
#  "'chamber psych', 'fourth world', 'indie folk', 'indie jazz', 'uk contemporary jazz'",
#  "'afrobeat', 'afropop', 'desert blues', 'malian blues', 'mande pop', 'world'",
#  "'blues', 'blues rock', 'country blues', 'country rock', 'folk', 'folk rock', 'mellow gold', 'piedmont blues', 'roots rock', 'singer-songwriter', 'traditional folk'",
#  "'canadian indie', 'indie folk', 'indie pop', 'new americana', 'stomp and holler'",
#  "'german house'",
#  "'edm', 'electropop', 'pop', 'pop dance', 'tropical house'",
#  "'electropop', 'indie pop', 'pop'",
#  "'alternative dance', 'auckland indie', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'kiwi rock', 'metropopolis', 'modern rock', 'shimmer pop'",
#  "'dixieland', 'jazz clarinet', 'new orleans jazz'",
#  "'irish neo-traditional'",
#  "'brisbane indie'",
#  "'australian garage punk'",
#  "'downtempo', 'electronica', 'livetronica', 'trip hop'",
#  "'australian hip hop'",
#  "'alternative dance', 'electronica'",
#  "'alternative country', 'queer country'",
#  "'chanson', 'french indie pop', 'french indietronica', 'french rock', 'nouvelle chanson francaise'",
#  "'belgian pop', 'variete francaise'",
#  "'neo-classical'",
#  "'electronica', 'hamburg electronic', 'microhouse', 'minimal techno'",
#  "'asian american hip hop', 'battle rap', 'k-rap'",
#  "'deep tech house', 'disco house', 'edm', 'house', 'pop dance', 'progressive house', 'tropical house'",
#  "'neo-psychedelic'",
#  "'bow pop', 'compositional ambient', 'icelandic classical', 'neo-classical', 'neoclassical darkwave'",
#  "'complextro', 'edm', 'electro house', 'filthstep', 'glitch'",
#  "'indie pop', 'portland indie', 'stomp and holler'",
#  "'indie pop', 'indie rock', 'indie singer-songwriter', 'maine indie'",
#  "'dark trap', 'drill', 'hip hop', 'miami hip hop', 'rap', 'trap', 'underground hip hop'",
#  "'trap', 'underground hip hop'",
#  "'reggae fusion'",
#  "'pop', 'post-teen pop'",
#  "'scottish indie'",
#  "'alternative dance', 'chillwave', 'dream pop', 'electropop', 'indie pop', 'indie rock', 'indietronica', 'metropopolis', 'modern rock', 'shimmer pop', 'vapor soul'",
#  "'art pop', 'dance pop', 'electropop', 'pop', 'swedish electropop', 'swedish indie pop', 'swedish pop'",
#  "'indie garage rock', 'indie pop', 'indie rock', 'modern rock', 'vapor soul'"]

# %%
len(genres)
# Out:
# 280

# %%
def remove_punct(text):
    text = re.sub('[\W_]+', ' ', text)
    return text

# %%
type(genres)
# Out:
# list

# %%
genre_1 = genres[0]

# %%
genre_1
# Out:
# "'alternative rock', 'garage rock', 'garage rock revival', 'indie rock', 'modern alternative rock', 'modern blues rock', 'modern rock', 'rock', 'supergroup'"

# %%
g1_np = remove_punct(genre_1)

# %%
g1_np
# Out:
# ' alternative rock garage rock garage rock revival indie rock modern alternative rock modern blues rock modern rock rock supergroup '

# %% [markdown]
# ^^^that's exactly what I want for each line. Now how to interate over each line and do that.

# %%
genres_np = []
count = 0

for genre in genres:
    if 'r&b' in genre:
        genre = genre.replace('r&b', 'rb')
    if 'lo-fi' in genre:    
        genre = genre.replace('lo-fi', 'lofi')
    g_np = remove_punct(genre)
    g_np = g_np.strip()
    genres_np.append(g_np)
    
genres_np
# Out:
# ['alternative rock garage rock garage rock revival indie rock modern alternative rock modern blues rock modern rock rock supergroup',
#  'vapor twitch',
#  'australian alternative pop australian pop',
#  'australian house bass house fidget house',
#  'chillwave downtempo electronica indietronica intelligent dance music',
#  'downtempo bass',
#  'indie pop',
#  'electropop modern alternative rock modern rock pixie pop pop emo pop punk rock',
#  'australian pop',
#  'uk pop',
#  'uk alternative pop',
#  'indie soul uk alternative pop',
#  'dance pop hip pop pop pop dance pop rap post teen pop rb urban contemporary',
#  'christian hip hop houston rap',
#  'bedroom pop boston indie',
#  'jawaiian reggae rock',
#  'reggae fusion reggae rock',
#  'aussietronica',
#  'aussietronica',
#  'alternative hip hop canadian modern jazz escape room funk hip hop indie soul',
#  'sydney indie',
#  'la pop pop',
#  'australian garage punk australian psych neo psychedelic',
#  'big beat downtempo electronica jazztronica ninja nu jazz trip hop',
#  'brisbane indie indie anthem folk',
#  'danish indie pop',
#  'art pop baroque pop chamber pop chicago indie freak folk indie folk indie pop indie rock melancholia stomp and holler',
#  'pop punk punk socal pop punk',
#  'edm electropop indie poptimism pop pop dance pop edm tropical house',
#  'deep tropical house pop edm tropical house',
#  'deep new americana funk indie folk retro soul',
#  'big room edm electro house electropop pop dance pop edm progressive electro house progressive house tropical house',
#  'australian alternative pop',
#  'australian garage punk australian indie rock',
#  'bedroom pop modern rock oakland indie pop',
#  'alternative dance dance punk electropop escape room new rave',
#  'alternative rb edm electropop indie electropop indie soul tropical house vapor soul vapor twitch',
#  'alternative rb gauze pop indie rb indie soul uk contemporary rb',
#  'instrumental math rock southeast asian post rock taiwan indie',
#  'conscious hip hop dmv rap hip hop pop rap rap',
#  'australian indie rock brisbane indie',
#  'australian hip hop australian trap',
#  'australian trap',
#  'deep tropical house electropop pop dance pop edm',
#  'australian hip hop',
#  'british alternative rock modern alternative rock modern rock pixie pop emo',
#  'boston rock neo mellow pop rock',
#  'gauze pop progressive house tropical house',
#  'art pop chillwave electropop metropopolis shimmer pop',
#  'kent indie',
#  'vapor pop',
#  'australian indie folk indie anthem folk',
#  'uk house',
#  'contemporary jazz funk rock jazz funk jazz fusion progressive jazz fusion',
#  'alternative rb edm indie soul pop uk dance vapor soul',
#  'bedroom pop boston indie',
#  'australian hip hop australian indie australian pop australian trap',
#  'australian indie indie dream pop',
#  'bubblegrunge indie pop indie rock minneapolis indie',
#  'edm progressive house progressive trance trance uplifting trance',
#  'electropop indie poptimism modern rock pop',
#  'chicago rap conscious hip hop hip hop political hip hop pop rap rap southern hip hop',
#  'indie electropop',
#  'aussietronica',
#  'adelaide indie australian garage punk garage psych',
#  'filter house indie soul',
#  'christian indie indiecoustica ok indie',
#  'alternative dance electrofox indie poptimism metropopolis northamptonshire indie shimmer pop',
#  'dfw rap melodic rap rap',
#  'australian indie australian pop fremantle indie metropopolis perth indie',
#  'ambeat',
#  'ambeat',
#  'ambeat chillhop',
#  'underground rap',
#  'ambeat',
#  'focus beats',
#  'aussie emo australian post hardcore newcastle nsw indie',
#  'electropop etherpop indie folk indie pop indie rock',
#  'australian indie australian pop',
#  'kawaii future bass lofi beats',
#  'electropop indie pop indie poptimism indietronica modern dream pop vapor soul',
#  'alternative dance alternative rock dance punk indie rock modern rock new rave rock',
#  'australian indie australian pop',
#  'chillhop downtempo japanese chillhop jazz rap',
#  'hawaiian hip hop',
#  'bass trap modern alternative rock traprun',
#  'australian garage punk australian indie australian indie rock fremantle indie perth indie',
#  'australian psych neo psychedelic',
#  'canadian indie kelowna bc indie vancouver indie',
#  'electropop pop',
#  'australian indie rock',
#  'australian reggae fusion australian ska ska jazz',
#  'art pop brooklyn indie chamber pop freak folk indie folk indie pop indie rock small room stomp and holler',
#  'electronica french indie pop french indietronica new french touch',
#  'canadian indie indie rock vancouver indie',
#  'indie anthem folk vapor soul',
#  'adelaide indie',
#  'aussie drill australian trap',
#  'aussie drill',
#  'american post rock compositional ambient post rock',
#  'art pop freak folk indie pop indie rock one person band',
#  'nz pop',
#  'indonesian edm',
#  'indonesian indie',
#  'new french touch',
#  'australian alternative pop',
#  'minneapolis indie',
#  'deep new americana indiecoustica stomp and holler',
#  'alternative roots rock garage rock modern alternative rock modern blues rock modern hard rock modern rock punk blues rock',
#  'downtempo electronica jazztronica ninja nu jazz trip hop',
#  'electronica future garage indie soul',
#  'alternative dance art pop dance pop electronica experimental pop experimental vocal icelandic experimental icelandic pop metropopolis permanent wave trip hop',
#  'bass music chillwave electronica microhouse ninja wonky',
#  'afrofuturism alternative rb art pop escape room indie soul la pop',
#  'oc indie',
#  'alternative rb indie rb',
#  'hip hop pittsburgh rap rap',
#  'art pop chillwave electronica indie soul',
#  'dancehall lovers rock modern reggae reggae fusion roots reggae',
#  'indie dream pop indie shoegaze metropopolis',
#  'tassie indie',
#  'alternative metal alternative rock blues rock modern rock nu metal palm desert scene rock stoner metal stoner rock',
#  'alternative dance dance punk indie pop indie rock modern rock new rave rock rock independant francais',
#  'auckland indie electropop etherpop indie electropop indie pop indie poptimism indietronica metropopolis nz pop pop shimmer pop tropical house vapor soul',
#  'german hip hop german pop pop rap',
#  'german pop german rb',
#  'indie cafe pop indiecoustica',
#  'alternative rb chill rb indie rb nyc pop pop vapor soul',
#  'indie anthem folk indie folk',
#  'indie pop indie poptimism indie rock minneapolis indie modern alternative rock modern rock',
#  'electropop indie electropop indie pop indie poptimism indie soul vapor soul',
#  'modern ska punk',
#  'adelaide indie',
#  'australian indie australian pop',
#  'chillstep vapor twitch',
#  'nz pop pop',
#  'australian garage punk australian indie australian pop',
#  'german indie german pop german rock',
#  'alternative rb bedroom pop indie cafe pop indie pop pop',
#  'alternative rb escape room indie rb indie soul neo soul',
#  'atl hip hop hip hop pop rap rap',
#  'alternative hip hop dmv rap hip hop sudanese pop',
#  'alternative dance dance punk electronica new rave',
#  'australian indie rock',
#  'indie folk indie rock modern alternative rock modern rock stomp and holler',
#  'seattle indie',
#  'dance pop electropop escape room pop post teen pop trap queen',
#  'nashville indie',
#  'reggae rock',
#  'jam band jamtronica livetronica',
#  'metropopolis nottingham indie',
#  'art pop canadian electropop chillwave edmonton indie electropop grave wave indietronica metropopolis shimmer pop vapor soul',
#  'downtempo bass',
#  'indie soul jazz pop',
#  'british soul uk alternative pop',
#  'australian electropop edm indietronica',
#  'downtempo electronica nu jazz trip hop',
#  'birmingham hip hop',
#  'vienna indie',
#  'baroque pop brooklyn indie',
#  'indie folk indie pop metropopolis shimmer pop stomp and holler stomp and whittle',
#  'jacksonville indie modern rock',
#  'freak folk philly indie stomp and holler',
#  'alternative pop rock modern alternative rock modern rock rock',
#  'underground hip hop',
#  'french indie pop french indietronica french synthpop indie soul new french touch',
#  'danish jazz danish modern jazz',
#  'electra',
#  'reggae fusion reggae rock',
#  'electropop metropopolis vapor pop',
#  'new french touch',
#  'deep underground hip hop indie pop rap pop rap',
#  'chillhop lofi beats',
#  'birmingham indie english indie rock modern alternative rock modern rock',
#  'pop rap',
#  'alternative hip hop big beat electronica hip hop jazztronica ninja nu jazz turntablism',
#  'indie pop indie rock',
#  'australian indie australian pop indie soul',
#  'cyberpunk synthwave',
#  'popwave spacewave synthwave',
#  'australian alternative pop australian indie shimmer pop',
#  'alternative dance big beat downtempo electronica electropop trip hop',
#  'indie pop nyc pop',
#  'comic conscious hip hop',
#  'australian dance',
#  'australian garage punk brisbane indie',
#  'escape room indie soul trap queen uk alternative hip hop',
#  'chicago soul classic soul funk memphis soul motown quiet storm soul southern soul',
#  'cali rap modern alternative rock',
#  'bounce escape room lgbtq hip hop new orleans rap trap queen',
#  'dance pop escape room minnesota hip hop pop pop dance pop rap trap queen',
#  'retro soul',
#  'french indie pop french indietronica new french touch',
#  'nova mpb',
#  'spanish modern rock',
#  'alternative dance indie soul new rave nu disco',
#  'la pop',
#  'edm electropop pop dance pop edm tropical house',
#  'dance pop electropop pop post teen pop viral pop',
#  'british jazz compositional ambient contemporary jazz electronica jazz quartet new tribe nu jazz',
#  'abstract hip hop comic modern rock pop rap',
#  'alternative rb aussietronica electropop indie electropop indie soul vapor soul',
#  'alternative dance vapor soul',
#  'australian indie',
#  'australian trap',
#  'rock independant francais',
#  'art pop bay area indie chillwave indie folk indie pop indie rock oakland indie small room',
#  'art pop bubblegrunge eugene indie indie pop indie rock philly indie',
#  'australian indie australian pop',
#  'reggae fusion reggae rock',
#  'austindie pop soul',
#  'st petersburg fl indie',
#  'gangster rap hyphy west coast rap west coast trap',
#  'arabic jazz french jazz jazz trumpet',
#  'aussietronica edm gauze pop house indie soul pop dance tropical house',
#  'candy pop dance pop electropop metropopolis pop pop dance swedish electropop swedish synthpop',
#  'nz pop',
#  'big room edm electro house pop dance pop edm progressive electro house progressive house progressive trance trance tropical house uplifting trance',
#  'korean dream pop',
#  'indie pop indie poptimism indie rock la indie modern alternative rock modern rock pop rock',
#  'indie cafe pop indie pop pop',
#  'instrumental rock',
#  'australian indie electropop vapor soul',
#  'electronica hamburg electronic microhouse minimal techno new french touch organic electronic pop ambient',
#  'australian hip hop',
#  'candy pop emo pixie pop emo pop punk',
#  'disco house filter house vocal house',
#  'classical piano turkish classical performance turkish jazz',
#  'taiwan classical performance',
#  'australian electropop',
#  'vapor pop',
#  'bedroom pop bubblegrunge indie pop',
#  'australian reggae fusion',
#  'indie jazz indie soul',
#  'alternative dance canadian indie canadian rock dance punk electropop indie pop indie rock indietronica metropopolis modern rock neo synthpop new rave rock shimmer pop',
#  'chillwave indie jazz wonky',
#  'australian indie rock',
#  'alternative hip hop atl hip hop conscious hip hop dirty south rap gangster rap hardcore hip hop hip hop rap southern hip hop trap',
#  'alternative hip hop bronx hip hop conscious hip hop east coast hip hop gangster rap hardcore hip hop hip hop old school hip hop political hip hop rap turntablism',
#  'alternative hip hop chicago rap conscious hip hop gangster rap hardcore hip hop hip hop neo soul political hip hop rap southern hip hop',
#  'ambeat jazz rap underground rap',
#  'electropop indie electropop indie poptimism',
#  'art pop bubblegrunge indie folk indie pop indie rock',
#  'alternative hip hop escape room experimental hip hop industrial hip hop',
#  'art pop chamber psych',
#  'chamber psych fourth world indie folk indie jazz uk contemporary jazz',
#  'afrobeat afropop desert blues malian blues mande pop world',
#  'blues blues rock country blues country rock folk folk rock mellow gold piedmont blues roots rock singer songwriter traditional folk',
#  'canadian indie indie folk indie pop new americana stomp and holler',
#  'german house',
#  'edm electropop pop pop dance tropical house',
#  'electropop indie pop pop',
#  'alternative dance auckland indie electropop indie pop indie rock indietronica kiwi rock metropopolis modern rock shimmer pop',
#  'dixieland jazz clarinet new orleans jazz',
#  'irish neo traditional',
#  'brisbane indie',
#  'australian garage punk',
#  'downtempo electronica livetronica trip hop',
#  'australian hip hop',
#  'alternative dance electronica',
#  'alternative country queer country',
#  'chanson french indie pop french indietronica french rock nouvelle chanson francaise',
#  'belgian pop variete francaise',
#  'neo classical',
#  'electronica hamburg electronic microhouse minimal techno',
#  'asian american hip hop battle rap k rap',
#  'deep tech house disco house edm house pop dance progressive house tropical house',
#  'neo psychedelic',
#  'bow pop compositional ambient icelandic classical neo classical neoclassical darkwave',
#  'complextro edm electro house filthstep glitch',
#  'indie pop portland indie stomp and holler',
#  'indie pop indie rock indie singer songwriter maine indie',
#  'dark trap drill hip hop miami hip hop rap trap underground hip hop',
#  'trap underground hip hop',
#  'reggae fusion',
#  'pop post teen pop',
#  'scottish indie',
#  'alternative dance chillwave dream pop electropop indie pop indie rock indietronica metropopolis modern rock shimmer pop vapor soul',
#  'art pop dance pop electropop pop swedish electropop swedish indie pop swedish pop',
#  'indie garage rock indie pop indie rock modern rock vapor soul']

# %%
big_genres = []

for genre in genres_np:
    genres_list = genre.split(' ')
    big_genres.append(genres_list)
    
big_genres
# Out:
# [['alternative',
#   'rock',
#   'garage',
#   'rock',
#   'garage',
#   'rock',
#   'revival',
#   'indie',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'blues',
#   'rock',
#   'modern',
#   'rock',
#   'rock',
#   'supergroup'],
#  ['vapor', 'twitch'],
#  ['australian', 'alternative', 'pop', 'australian', 'pop'],
#  ['australian', 'house', 'bass', 'house', 'fidget', 'house'],
#  ['chillwave',
#   'downtempo',
#   'electronica',
#   'indietronica',
#   'intelligent',
#   'dance',
#   'music'],
#  ['downtempo', 'bass'],
#  ['indie', 'pop'],
#  ['electropop',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock',
#   'pixie',
#   'pop',
#   'pop',
#   'emo',
#   'pop',
#   'punk',
#   'rock'],
#  ['australian', 'pop'],
#  ['uk', 'pop'],
#  ['uk', 'alternative', 'pop'],
#  ['indie', 'soul', 'uk', 'alternative', 'pop'],
#  ['dance',
#   'pop',
#   'hip',
#   'pop',
#   'pop',
#   'pop',
#   'dance',
#   'pop',
#   'rap',
#   'post',
#   'teen',
#   'pop',
#   'rb',
#   'urban',
#   'contemporary'],
#  ['christian', 'hip', 'hop', 'houston', 'rap'],
#  ['bedroom', 'pop', 'boston', 'indie'],
#  ['jawaiian', 'reggae', 'rock'],
#  ['reggae', 'fusion', 'reggae', 'rock'],
#  ['aussietronica'],
#  ['aussietronica'],
#  ['alternative',
#   'hip',
#   'hop',
#   'canadian',
#   'modern',
#   'jazz',
#   'escape',
#   'room',
#   'funk',
#   'hip',
#   'hop',
#   'indie',
#   'soul'],
#  ['sydney', 'indie'],
#  ['la', 'pop', 'pop'],
#  ['australian', 'garage', 'punk', 'australian', 'psych', 'neo', 'psychedelic'],
#  ['big',
#   'beat',
#   'downtempo',
#   'electronica',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'jazz',
#   'trip',
#   'hop'],
#  ['brisbane', 'indie', 'indie', 'anthem', 'folk'],
#  ['danish', 'indie', 'pop'],
#  ['art',
#   'pop',
#   'baroque',
#   'pop',
#   'chamber',
#   'pop',
#   'chicago',
#   'indie',
#   'freak',
#   'folk',
#   'indie',
#   'folk',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'melancholia',
#   'stomp',
#   'and',
#   'holler'],
#  ['pop', 'punk', 'punk', 'socal', 'pop', 'punk'],
#  ['edm',
#   'electropop',
#   'indie',
#   'poptimism',
#   'pop',
#   'pop',
#   'dance',
#   'pop',
#   'edm',
#   'tropical',
#   'house'],
#  ['deep', 'tropical', 'house', 'pop', 'edm', 'tropical', 'house'],
#  ['deep', 'new', 'americana', 'funk', 'indie', 'folk', 'retro', 'soul'],
#  ['big',
#   'room',
#   'edm',
#   'electro',
#   'house',
#   'electropop',
#   'pop',
#   'dance',
#   'pop',
#   'edm',
#   'progressive',
#   'electro',
#   'house',
#   'progressive',
#   'house',
#   'tropical',
#   'house'],
#  ['australian', 'alternative', 'pop'],
#  ['australian', 'garage', 'punk', 'australian', 'indie', 'rock'],
#  ['bedroom', 'pop', 'modern', 'rock', 'oakland', 'indie', 'pop'],
#  ['alternative',
#   'dance',
#   'dance',
#   'punk',
#   'electropop',
#   'escape',
#   'room',
#   'new',
#   'rave'],
#  ['alternative',
#   'rb',
#   'edm',
#   'electropop',
#   'indie',
#   'electropop',
#   'indie',
#   'soul',
#   'tropical',
#   'house',
#   'vapor',
#   'soul',
#   'vapor',
#   'twitch'],
#  ['alternative',
#   'rb',
#   'gauze',
#   'pop',
#   'indie',
#   'rb',
#   'indie',
#   'soul',
#   'uk',
#   'contemporary',
#   'rb'],
#  ['instrumental',
#   'math',
#   'rock',
#   'southeast',
#   'asian',
#   'post',
#   'rock',
#   'taiwan',
#   'indie'],
#  ['conscious', 'hip', 'hop', 'dmv', 'rap', 'hip', 'hop', 'pop', 'rap', 'rap'],
#  ['australian', 'indie', 'rock', 'brisbane', 'indie'],
#  ['australian', 'hip', 'hop', 'australian', 'trap'],
#  ['australian', 'trap'],
#  ['deep', 'tropical', 'house', 'electropop', 'pop', 'dance', 'pop', 'edm'],
#  ['australian', 'hip', 'hop'],
#  ['british',
#   'alternative',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock',
#   'pixie',
#   'pop',
#   'emo'],
#  ['boston', 'rock', 'neo', 'mellow', 'pop', 'rock'],
#  ['gauze', 'pop', 'progressive', 'house', 'tropical', 'house'],
#  ['art', 'pop', 'chillwave', 'electropop', 'metropopolis', 'shimmer', 'pop'],
#  ['kent', 'indie'],
#  ['vapor', 'pop'],
#  ['australian', 'indie', 'folk', 'indie', 'anthem', 'folk'],
#  ['uk', 'house'],
#  ['contemporary',
#   'jazz',
#   'funk',
#   'rock',
#   'jazz',
#   'funk',
#   'jazz',
#   'fusion',
#   'progressive',
#   'jazz',
#   'fusion'],
#  ['alternative',
#   'rb',
#   'edm',
#   'indie',
#   'soul',
#   'pop',
#   'uk',
#   'dance',
#   'vapor',
#   'soul'],
#  ['bedroom', 'pop', 'boston', 'indie'],
#  ['australian',
#   'hip',
#   'hop',
#   'australian',
#   'indie',
#   'australian',
#   'pop',
#   'australian',
#   'trap'],
#  ['australian', 'indie', 'indie', 'dream', 'pop'],
#  ['bubblegrunge', 'indie', 'pop', 'indie', 'rock', 'minneapolis', 'indie'],
#  ['edm',
#   'progressive',
#   'house',
#   'progressive',
#   'trance',
#   'trance',
#   'uplifting',
#   'trance'],
#  ['electropop', 'indie', 'poptimism', 'modern', 'rock', 'pop'],
#  ['chicago',
#   'rap',
#   'conscious',
#   'hip',
#   'hop',
#   'hip',
#   'hop',
#   'political',
#   'hip',
#   'hop',
#   'pop',
#   'rap',
#   'rap',
#   'southern',
#   'hip',
#   'hop'],
#  ['indie', 'electropop'],
#  ['aussietronica'],
#  ['adelaide', 'indie', 'australian', 'garage', 'punk', 'garage', 'psych'],
#  ['filter', 'house', 'indie', 'soul'],
#  ['christian', 'indie', 'indiecoustica', 'ok', 'indie'],
#  ['alternative',
#   'dance',
#   'electrofox',
#   'indie',
#   'poptimism',
#   'metropopolis',
#   'northamptonshire',
#   'indie',
#   'shimmer',
#   'pop'],
#  ['dfw', 'rap', 'melodic', 'rap', 'rap'],
#  ['australian',
#   'indie',
#   'australian',
#   'pop',
#   'fremantle',
#   'indie',
#   'metropopolis',
#   'perth',
#   'indie'],
#  ['ambeat'],
#  ['ambeat'],
#  ['ambeat', 'chillhop'],
#  ['underground', 'rap'],
#  ['ambeat'],
#  ['focus', 'beats'],
#  ['aussie',
#   'emo',
#   'australian',
#   'post',
#   'hardcore',
#   'newcastle',
#   'nsw',
#   'indie'],
#  ['electropop', 'etherpop', 'indie', 'folk', 'indie', 'pop', 'indie', 'rock'],
#  ['australian', 'indie', 'australian', 'pop'],
#  ['kawaii', 'future', 'bass', 'lofi', 'beats'],
#  ['electropop',
#   'indie',
#   'pop',
#   'indie',
#   'poptimism',
#   'indietronica',
#   'modern',
#   'dream',
#   'pop',
#   'vapor',
#   'soul'],
#  ['alternative',
#   'dance',
#   'alternative',
#   'rock',
#   'dance',
#   'punk',
#   'indie',
#   'rock',
#   'modern',
#   'rock',
#   'new',
#   'rave',
#   'rock'],
#  ['australian', 'indie', 'australian', 'pop'],
#  ['chillhop', 'downtempo', 'japanese', 'chillhop', 'jazz', 'rap'],
#  ['hawaiian', 'hip', 'hop'],
#  ['bass', 'trap', 'modern', 'alternative', 'rock', 'traprun'],
#  ['australian',
#   'garage',
#   'punk',
#   'australian',
#   'indie',
#   'australian',
#   'indie',
#   'rock',
#   'fremantle',
#   'indie',
#   'perth',
#   'indie'],
#  ['australian', 'psych', 'neo', 'psychedelic'],
#  ['canadian', 'indie', 'kelowna', 'bc', 'indie', 'vancouver', 'indie'],
#  ['electropop', 'pop'],
#  ['australian', 'indie', 'rock'],
#  ['australian', 'reggae', 'fusion', 'australian', 'ska', 'ska', 'jazz'],
#  ['art',
#   'pop',
#   'brooklyn',
#   'indie',
#   'chamber',
#   'pop',
#   'freak',
#   'folk',
#   'indie',
#   'folk',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'small',
#   'room',
#   'stomp',
#   'and',
#   'holler'],
#  ['electronica',
#   'french',
#   'indie',
#   'pop',
#   'french',
#   'indietronica',
#   'new',
#   'french',
#   'touch'],
#  ['canadian', 'indie', 'indie', 'rock', 'vancouver', 'indie'],
#  ['indie', 'anthem', 'folk', 'vapor', 'soul'],
#  ['adelaide', 'indie'],
#  ['aussie', 'drill', 'australian', 'trap'],
#  ['aussie', 'drill'],
#  ['american', 'post', 'rock', 'compositional', 'ambient', 'post', 'rock'],
#  ['art',
#   'pop',
#   'freak',
#   'folk',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'one',
#   'person',
#   'band'],
#  ['nz', 'pop'],
#  ['indonesian', 'edm'],
#  ['indonesian', 'indie'],
#  ['new', 'french', 'touch'],
#  ['australian', 'alternative', 'pop'],
#  ['minneapolis', 'indie'],
#  ['deep', 'new', 'americana', 'indiecoustica', 'stomp', 'and', 'holler'],
#  ['alternative',
#   'roots',
#   'rock',
#   'garage',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'blues',
#   'rock',
#   'modern',
#   'hard',
#   'rock',
#   'modern',
#   'rock',
#   'punk',
#   'blues',
#   'rock'],
#  ['downtempo',
#   'electronica',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'jazz',
#   'trip',
#   'hop'],
#  ['electronica', 'future', 'garage', 'indie', 'soul'],
#  ['alternative',
#   'dance',
#   'art',
#   'pop',
#   'dance',
#   'pop',
#   'electronica',
#   'experimental',
#   'pop',
#   'experimental',
#   'vocal',
#   'icelandic',
#   'experimental',
#   'icelandic',
#   'pop',
#   'metropopolis',
#   'permanent',
#   'wave',
#   'trip',
#   'hop'],
#  ['bass', 'music', 'chillwave', 'electronica', 'microhouse', 'ninja', 'wonky'],
#  ['afrofuturism',
#   'alternative',
#   'rb',
#   'art',
#   'pop',
#   'escape',
#   'room',
#   'indie',
#   'soul',
#   'la',
#   'pop'],
#  ['oc', 'indie'],
#  ['alternative', 'rb', 'indie', 'rb'],
#  ['hip', 'hop', 'pittsburgh', 'rap', 'rap'],
#  ['art', 'pop', 'chillwave', 'electronica', 'indie', 'soul'],
#  ['dancehall',
#   'lovers',
#   'rock',
#   'modern',
#   'reggae',
#   'reggae',
#   'fusion',
#   'roots',
#   'reggae'],
#  ['indie', 'dream', 'pop', 'indie', 'shoegaze', 'metropopolis'],
#  ['tassie', 'indie'],
#  ['alternative',
#   'metal',
#   'alternative',
#   'rock',
#   'blues',
#   'rock',
#   'modern',
#   'rock',
#   'nu',
#   'metal',
#   'palm',
#   'desert',
#   'scene',
#   'rock',
#   'stoner',
#   'metal',
#   'stoner',
#   'rock'],
#  ['alternative',
#   'dance',
#   'dance',
#   'punk',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'modern',
#   'rock',
#   'new',
#   'rave',
#   'rock',
#   'rock',
#   'independant',
#   'francais'],
#  ['auckland',
#   'indie',
#   'electropop',
#   'etherpop',
#   'indie',
#   'electropop',
#   'indie',
#   'pop',
#   'indie',
#   'poptimism',
#   'indietronica',
#   'metropopolis',
#   'nz',
#   'pop',
#   'pop',
#   'shimmer',
#   'pop',
#   'tropical',
#   'house',
#   'vapor',
#   'soul'],
#  ['german', 'hip', 'hop', 'german', 'pop', 'pop', 'rap'],
#  ['german', 'pop', 'german', 'rb'],
#  ['indie', 'cafe', 'pop', 'indiecoustica'],
#  ['alternative',
#   'rb',
#   'chill',
#   'rb',
#   'indie',
#   'rb',
#   'nyc',
#   'pop',
#   'pop',
#   'vapor',
#   'soul'],
#  ['indie', 'anthem', 'folk', 'indie', 'folk'],
#  ['indie',
#   'pop',
#   'indie',
#   'poptimism',
#   'indie',
#   'rock',
#   'minneapolis',
#   'indie',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock'],
#  ['electropop',
#   'indie',
#   'electropop',
#   'indie',
#   'pop',
#   'indie',
#   'poptimism',
#   'indie',
#   'soul',
#   'vapor',
#   'soul'],
#  ['modern', 'ska', 'punk'],
#  ['adelaide', 'indie'],
#  ['australian', 'indie', 'australian', 'pop'],
#  ['chillstep', 'vapor', 'twitch'],
#  ['nz', 'pop', 'pop'],
#  ['australian', 'garage', 'punk', 'australian', 'indie', 'australian', 'pop'],
#  ['german', 'indie', 'german', 'pop', 'german', 'rock'],
#  ['alternative',
#   'rb',
#   'bedroom',
#   'pop',
#   'indie',
#   'cafe',
#   'pop',
#   'indie',
#   'pop',
#   'pop'],
#  ['alternative',
#   'rb',
#   'escape',
#   'room',
#   'indie',
#   'rb',
#   'indie',
#   'soul',
#   'neo',
#   'soul'],
#  ['atl', 'hip', 'hop', 'hip', 'hop', 'pop', 'rap', 'rap'],
#  ['alternative', 'hip', 'hop', 'dmv', 'rap', 'hip', 'hop', 'sudanese', 'pop'],
#  ['alternative', 'dance', 'dance', 'punk', 'electronica', 'new', 'rave'],
#  ['australian', 'indie', 'rock'],
#  ['indie',
#   'folk',
#   'indie',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock',
#   'stomp',
#   'and',
#   'holler'],
#  ['seattle', 'indie'],
#  ['dance',
#   'pop',
#   'electropop',
#   'escape',
#   'room',
#   'pop',
#   'post',
#   'teen',
#   'pop',
#   'trap',
#   'queen'],
#  ['nashville', 'indie'],
#  ['reggae', 'rock'],
#  ['jam', 'band', 'jamtronica', 'livetronica'],
#  ['metropopolis', 'nottingham', 'indie'],
#  ['art',
#   'pop',
#   'canadian',
#   'electropop',
#   'chillwave',
#   'edmonton',
#   'indie',
#   'electropop',
#   'grave',
#   'wave',
#   'indietronica',
#   'metropopolis',
#   'shimmer',
#   'pop',
#   'vapor',
#   'soul'],
#  ['downtempo', 'bass'],
#  ['indie', 'soul', 'jazz', 'pop'],
#  ['british', 'soul', 'uk', 'alternative', 'pop'],
#  ['australian', 'electropop', 'edm', 'indietronica'],
#  ['downtempo', 'electronica', 'nu', 'jazz', 'trip', 'hop'],
#  ['birmingham', 'hip', 'hop'],
#  ['vienna', 'indie'],
#  ['baroque', 'pop', 'brooklyn', 'indie'],
#  ['indie',
#   'folk',
#   'indie',
#   'pop',
#   'metropopolis',
#   'shimmer',
#   'pop',
#   'stomp',
#   'and',
#   'holler',
#   'stomp',
#   'and',
#   'whittle'],
#  ['jacksonville', 'indie', 'modern', 'rock'],
#  ['freak', 'folk', 'philly', 'indie', 'stomp', 'and', 'holler'],
#  ['alternative',
#   'pop',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock',
#   'rock'],
#  ['underground', 'hip', 'hop'],
#  ['french',
#   'indie',
#   'pop',
#   'french',
#   'indietronica',
#   'french',
#   'synthpop',
#   'indie',
#   'soul',
#   'new',
#   'french',
#   'touch'],
#  ['danish', 'jazz', 'danish', 'modern', 'jazz'],
#  ['electra'],
#  ['reggae', 'fusion', 'reggae', 'rock'],
#  ['electropop', 'metropopolis', 'vapor', 'pop'],
#  ['new', 'french', 'touch'],
#  ['deep', 'underground', 'hip', 'hop', 'indie', 'pop', 'rap', 'pop', 'rap'],
#  ['chillhop', 'lofi', 'beats'],
#  ['birmingham',
#   'indie',
#   'english',
#   'indie',
#   'rock',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock'],
#  ['pop', 'rap'],
#  ['alternative',
#   'hip',
#   'hop',
#   'big',
#   'beat',
#   'electronica',
#   'hip',
#   'hop',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'jazz',
#   'turntablism'],
#  ['indie', 'pop', 'indie', 'rock'],
#  ['australian', 'indie', 'australian', 'pop', 'indie', 'soul'],
#  ['cyberpunk', 'synthwave'],
#  ['popwave', 'spacewave', 'synthwave'],
#  ['australian', 'alternative', 'pop', 'australian', 'indie', 'shimmer', 'pop'],
#  ['alternative',
#   'dance',
#   'big',
#   'beat',
#   'downtempo',
#   'electronica',
#   'electropop',
#   'trip',
#   'hop'],
#  ['indie', 'pop', 'nyc', 'pop'],
#  ['comic', 'conscious', 'hip', 'hop'],
#  ['australian', 'dance'],
#  ['australian', 'garage', 'punk', 'brisbane', 'indie'],
#  ['escape',
#   'room',
#   'indie',
#   'soul',
#   'trap',
#   'queen',
#   'uk',
#   'alternative',
#   'hip',
#   'hop'],
#  ['chicago',
#   'soul',
#   'classic',
#   'soul',
#   'funk',
#   'memphis',
#   'soul',
#   'motown',
#   'quiet',
#   'storm',
#   'soul',
#   'southern',
#   'soul'],
#  ['cali', 'rap', 'modern', 'alternative', 'rock'],
#  ['bounce',
#   'escape',
#   'room',
#   'lgbtq',
#   'hip',
#   'hop',
#   'new',
#   'orleans',
#   'rap',
#   'trap',
#   'queen'],
#  ['dance',
#   'pop',
#   'escape',
#   'room',
#   'minnesota',
#   'hip',
#   'hop',
#   'pop',
#   'pop',
#   'dance',
#   'pop',
#   'rap',
#   'trap',
#   'queen'],
#  ['retro', 'soul'],
#  ['french',
#   'indie',
#   'pop',
#   'french',
#   'indietronica',
#   'new',
#   'french',
#   'touch'],
#  ['nova', 'mpb'],
#  ['spanish', 'modern', 'rock'],
#  ['alternative', 'dance', 'indie', 'soul', 'new', 'rave', 'nu', 'disco'],
#  ['la', 'pop'],
#  ['edm', 'electropop', 'pop', 'dance', 'pop', 'edm', 'tropical', 'house'],
#  ['dance', 'pop', 'electropop', 'pop', 'post', 'teen', 'pop', 'viral', 'pop'],
#  ['british',
#   'jazz',
#   'compositional',
#   'ambient',
#   'contemporary',
#   'jazz',
#   'electronica',
#   'jazz',
#   'quartet',
#   'new',
#   'tribe',
#   'nu',
#   'jazz'],
#  ['abstract', 'hip', 'hop', 'comic', 'modern', 'rock', 'pop', 'rap'],
#  ['alternative',
#   'rb',
#   'aussietronica',
#   'electropop',
#   'indie',
#   'electropop',
#   'indie',
#   'soul',
#   'vapor',
#   'soul'],
#  ['alternative', 'dance', 'vapor', 'soul'],
#  ['australian', 'indie'],
#  ['australian', 'trap'],
#  ['rock', 'independant', 'francais'],
#  ['art',
#   'pop',
#   'bay',
#   'area',
#   'indie',
#   'chillwave',
#   'indie',
#   'folk',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'oakland',
#   'indie',
#   'small',
#   'room'],
#  ['art',
#   'pop',
#   'bubblegrunge',
#   'eugene',
#   'indie',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'philly',
#   'indie'],
#  ['australian', 'indie', 'australian', 'pop'],
#  ['reggae', 'fusion', 'reggae', 'rock'],
#  ['austindie', 'pop', 'soul'],
#  ['st', 'petersburg', 'fl', 'indie'],
#  ['gangster', 'rap', 'hyphy', 'west', 'coast', 'rap', 'west', 'coast', 'trap'],
#  ['arabic', 'jazz', 'french', 'jazz', 'jazz', 'trumpet'],
#  ['aussietronica',
#   'edm',
#   'gauze',
#   'pop',
#   'house',
#   'indie',
#   'soul',
#   'pop',
#   'dance',
#   'tropical',
#   'house'],
#  ['candy',
#   'pop',
#   'dance',
#   'pop',
#   'electropop',
#   'metropopolis',
#   'pop',
#   'pop',
#   'dance',
#   'swedish',
#   'electropop',
#   'swedish',
#   'synthpop'],
#  ['nz', 'pop'],
#  ['big',
#   'room',
#   'edm',
#   'electro',
#   'house',
#   'pop',
#   'dance',
#   'pop',
#   'edm',
#   'progressive',
#   'electro',
#   'house',
#   'progressive',
#   'house',
#   'progressive',
#   'trance',
#   'trance',
#   'tropical',
#   'house',
#   'uplifting',
#   'trance'],
#  ['korean', 'dream', 'pop'],
#  ['indie',
#   'pop',
#   'indie',
#   'poptimism',
#   'indie',
#   'rock',
#   'la',
#   'indie',
#   'modern',
#   'alternative',
#   'rock',
#   'modern',
#   'rock',
#   'pop',
#   'rock'],
#  ['indie', 'cafe', 'pop', 'indie', 'pop', 'pop'],
#  ['instrumental', 'rock'],
#  ['australian', 'indie', 'electropop', 'vapor', 'soul'],
#  ['electronica',
#   'hamburg',
#   'electronic',
#   'microhouse',
#   'minimal',
#   'techno',
#   'new',
#   'french',
#   'touch',
#   'organic',
#   'electronic',
#   'pop',
#   'ambient'],
#  ['australian', 'hip', 'hop'],
#  ['candy', 'pop', 'emo', 'pixie', 'pop', 'emo', 'pop', 'punk'],
#  ['disco', 'house', 'filter', 'house', 'vocal', 'house'],
#  ['classical',
#   'piano',
#   'turkish',
#   'classical',
#   'performance',
#   'turkish',
#   'jazz'],
#  ['taiwan', 'classical', 'performance'],
#  ['australian', 'electropop'],
#  ['vapor', 'pop'],
#  ['bedroom', 'pop', 'bubblegrunge', 'indie', 'pop'],
#  ['australian', 'reggae', 'fusion'],
#  ['indie', 'jazz', 'indie', 'soul'],
#  ['alternative',
#   'dance',
#   'canadian',
#   'indie',
#   'canadian',
#   'rock',
#   'dance',
#   'punk',
#   'electropop',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'indietronica',
#   'metropopolis',
#   'modern',
#   'rock',
#   'neo',
#   'synthpop',
#   'new',
#   'rave',
#   'rock',
#   'shimmer',
#   'pop'],
#  ['chillwave', 'indie', 'jazz', 'wonky'],
#  ['australian', 'indie', 'rock'],
#  ['alternative',
#   'hip',
#   'hop',
#   'atl',
#   'hip',
#   'hop',
#   'conscious',
#   'hip',
#   'hop',
#   'dirty',
#   'south',
#   'rap',
#   'gangster',
#   'rap',
#   'hardcore',
#   'hip',
#   'hop',
#   'hip',
#   'hop',
#   'rap',
#   'southern',
#   'hip',
#   'hop',
#   'trap'],
#  ['alternative',
#   'hip',
#   'hop',
#   'bronx',
#   'hip',
#   'hop',
#   'conscious',
#   'hip',
#   'hop',
#   'east',
#   'coast',
#   'hip',
#   'hop',
#   'gangster',
#   'rap',
#   'hardcore',
#   'hip',
#   'hop',
#   'hip',
#   'hop',
#   'old',
#   'school',
#   'hip',
#   'hop',
#   'political',
#   'hip',
#   'hop',
#   'rap',
#   'turntablism'],
#  ['alternative',
#   'hip',
#   'hop',
#   'chicago',
#   'rap',
#   'conscious',
#   'hip',
#   'hop',
#   'gangster',
#   'rap',
#   'hardcore',
#   'hip',
#   'hop',
#   'hip',
#   'hop',
#   'neo',
#   'soul',
#   'political',
#   'hip',
#   'hop',
#   'rap',
#   'southern',
#   'hip',
#   'hop'],
#  ['ambeat', 'jazz', 'rap', 'underground', 'rap'],
#  ['electropop', 'indie', 'electropop', 'indie', 'poptimism'],
#  ['art',
#   'pop',
#   'bubblegrunge',
#   'indie',
#   'folk',
#   'indie',
#   'pop',
#   'indie',
#   'rock'],
#  ['alternative',
#   'hip',
#   'hop',
#   'escape',
#   'room',
#   'experimental',
#   'hip',
#   'hop',
#   'industrial',
#   'hip',
#   'hop'],
#  ['art', 'pop', 'chamber', 'psych'],
#  ['chamber',
#   'psych',
#   'fourth',
#   'world',
#   'indie',
#   'folk',
#   'indie',
#   'jazz',
#   'uk',
#   'contemporary',
#   'jazz'],
#  ['afrobeat',
#   'afropop',
#   'desert',
#   'blues',
#   'malian',
#   'blues',
#   'mande',
#   'pop',
#   'world'],
#  ['blues',
#   'blues',
#   'rock',
#   'country',
#   'blues',
#   'country',
#   'rock',
#   'folk',
#   'folk',
#   'rock',
#   'mellow',
#   'gold',
#   'piedmont',
#   'blues',
#   'roots',
#   'rock',
#   'singer',
#   'songwriter',
#   'traditional',
#   'folk'],
#  ['canadian',
#   'indie',
#   'indie',
#   'folk',
#   'indie',
#   'pop',
#   'new',
#   'americana',
#   'stomp',
#   'and',
#   'holler'],
#  ['german', 'house'],
#  ['edm', 'electropop', 'pop', 'pop', 'dance', 'tropical', 'house'],
#  ['electropop', 'indie', 'pop', 'pop'],
#  ['alternative',
#   'dance',
#   'auckland',
#   'indie',
#   'electropop',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'indietronica',
#   'kiwi',
#   'rock',
#   'metropopolis',
#   'modern',
#   'rock',
#   'shimmer',
#   'pop'],
#  ['dixieland', 'jazz', 'clarinet', 'new', 'orleans', 'jazz'],
#  ['irish', 'neo', 'traditional'],
#  ['brisbane', 'indie'],
#  ['australian', 'garage', 'punk'],
#  ['downtempo', 'electronica', 'livetronica', 'trip', 'hop'],
#  ['australian', 'hip', 'hop'],
#  ['alternative', 'dance', 'electronica'],
#  ['alternative', 'country', 'queer', 'country'],
#  ['chanson',
#   'french',
#   'indie',
#   'pop',
#   'french',
#   'indietronica',
#   'french',
#   'rock',
#   'nouvelle',
#   'chanson',
#   'francaise'],
#  ['belgian', 'pop', 'variete', 'francaise'],
#  ['neo', 'classical'],
#  ['electronica', 'hamburg', 'electronic', 'microhouse', 'minimal', 'techno'],
#  ['asian', 'american', 'hip', 'hop', 'battle', 'rap', 'k', 'rap'],
#  ['deep',
#   'tech',
#   'house',
#   'disco',
#   'house',
#   'edm',
#   'house',
#   'pop',
#   'dance',
#   'progressive',
#   'house',
#   'tropical',
#   'house'],
#  ['neo', 'psychedelic'],
#  ['bow',
#   'pop',
#   'compositional',
#   'ambient',
#   'icelandic',
#   'classical',
#   'neo',
#   'classical',
#   'neoclassical',
#   'darkwave'],
#  ['complextro', 'edm', 'electro', 'house', 'filthstep', 'glitch'],
#  ['indie', 'pop', 'portland', 'indie', 'stomp', 'and', 'holler'],
#  ['indie',
#   'pop',
#   'indie',
#   'rock',
#   'indie',
#   'singer',
#   'songwriter',
#   'maine',
#   'indie'],
#  ['dark',
#   'trap',
#   'drill',
#   'hip',
#   'hop',
#   'miami',
#   'hip',
#   'hop',
#   'rap',
#   'trap',
#   'underground',
#   'hip',
#   'hop'],
#  ['trap', 'underground', 'hip', 'hop'],
#  ['reggae', 'fusion'],
#  ['pop', 'post', 'teen', 'pop'],
#  ['scottish', 'indie'],
#  ['alternative',
#   'dance',
#   'chillwave',
#   'dream',
#   'pop',
#   'electropop',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'indietronica',
#   'metropopolis',
#   'modern',
#   'rock',
#   'shimmer',
#   'pop',
#   'vapor',
#   'soul'],
#  ['art',
#   'pop',
#   'dance',
#   'pop',
#   'electropop',
#   'pop',
#   'swedish',
#   'electropop',
#   'swedish',
#   'indie',
#   'pop',
#   'swedish',
#   'pop'],
#  ['indie',
#   'garage',
#   'rock',
#   'indie',
#   'pop',
#   'indie',
#   'rock',
#   'modern',
#   'rock',
#   'vapor',
#   'soul']]

# %%
genres_set = []

for genres in big_genres:
    genres_list = set(genres)
    genres_set.append(genres_list)
    
genres_set
# Out:
# [{'alternative',
#   'blues',
#   'garage',
#   'indie',
#   'modern',
#   'revival',
#   'rock',
#   'supergroup'},
#  {'twitch', 'vapor'},
#  {'alternative', 'australian', 'pop'},
#  {'australian', 'bass', 'fidget', 'house'},
#  {'chillwave',
#   'dance',
#   'downtempo',
#   'electronica',
#   'indietronica',
#   'intelligent',
#   'music'},
#  {'bass', 'downtempo'},
#  {'indie', 'pop'},
#  {'alternative',
#   'electropop',
#   'emo',
#   'modern',
#   'pixie',
#   'pop',
#   'punk',
#   'rock'},
#  {'australian', 'pop'},
#  {'pop', 'uk'},
#  {'alternative', 'pop', 'uk'},
#  {'alternative', 'indie', 'pop', 'soul', 'uk'},
#  {'contemporary', 'dance', 'hip', 'pop', 'post', 'rap', 'rb', 'teen', 'urban'},
#  {'christian', 'hip', 'hop', 'houston', 'rap'},
#  {'bedroom', 'boston', 'indie', 'pop'},
#  {'jawaiian', 'reggae', 'rock'},
#  {'fusion', 'reggae', 'rock'},
#  {'aussietronica'},
#  {'aussietronica'},
#  {'alternative',
#   'canadian',
#   'escape',
#   'funk',
#   'hip',
#   'hop',
#   'indie',
#   'jazz',
#   'modern',
#   'room',
#   'soul'},
#  {'indie', 'sydney'},
#  {'la', 'pop'},
#  {'australian', 'garage', 'neo', 'psych', 'psychedelic', 'punk'},
#  {'beat',
#   'big',
#   'downtempo',
#   'electronica',
#   'hop',
#   'jazz',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'trip'},
#  {'anthem', 'brisbane', 'folk', 'indie'},
#  {'danish', 'indie', 'pop'},
#  {'and',
#   'art',
#   'baroque',
#   'chamber',
#   'chicago',
#   'folk',
#   'freak',
#   'holler',
#   'indie',
#   'melancholia',
#   'pop',
#   'rock',
#   'stomp'},
#  {'pop', 'punk', 'socal'},
#  {'dance',
#   'edm',
#   'electropop',
#   'house',
#   'indie',
#   'pop',
#   'poptimism',
#   'tropical'},
#  {'deep', 'edm', 'house', 'pop', 'tropical'},
#  {'americana', 'deep', 'folk', 'funk', 'indie', 'new', 'retro', 'soul'},
#  {'big',
#   'dance',
#   'edm',
#   'electro',
#   'electropop',
#   'house',
#   'pop',
#   'progressive',
#   'room',
#   'tropical'},
#  {'alternative', 'australian', 'pop'},
#  {'australian', 'garage', 'indie', 'punk', 'rock'},
#  {'bedroom', 'indie', 'modern', 'oakland', 'pop', 'rock'},
#  {'alternative',
#   'dance',
#   'electropop',
#   'escape',
#   'new',
#   'punk',
#   'rave',
#   'room'},
#  {'alternative',
#   'edm',
#   'electropop',
#   'house',
#   'indie',
#   'rb',
#   'soul',
#   'tropical',
#   'twitch',
#   'vapor'},
#  {'alternative', 'contemporary', 'gauze', 'indie', 'pop', 'rb', 'soul', 'uk'},
#  {'asian',
#   'indie',
#   'instrumental',
#   'math',
#   'post',
#   'rock',
#   'southeast',
#   'taiwan'},
#  {'conscious', 'dmv', 'hip', 'hop', 'pop', 'rap'},
#  {'australian', 'brisbane', 'indie', 'rock'},
#  {'australian', 'hip', 'hop', 'trap'},
#  {'australian', 'trap'},
#  {'dance', 'deep', 'edm', 'electropop', 'house', 'pop', 'tropical'},
#  {'australian', 'hip', 'hop'},
#  {'alternative', 'british', 'emo', 'modern', 'pixie', 'pop', 'rock'},
#  {'boston', 'mellow', 'neo', 'pop', 'rock'},
#  {'gauze', 'house', 'pop', 'progressive', 'tropical'},
#  {'art', 'chillwave', 'electropop', 'metropopolis', 'pop', 'shimmer'},
#  {'indie', 'kent'},
#  {'pop', 'vapor'},
#  {'anthem', 'australian', 'folk', 'indie'},
#  {'house', 'uk'},
#  {'contemporary', 'funk', 'fusion', 'jazz', 'progressive', 'rock'},
#  {'alternative', 'dance', 'edm', 'indie', 'pop', 'rb', 'soul', 'uk', 'vapor'},
#  {'bedroom', 'boston', 'indie', 'pop'},
#  {'australian', 'hip', 'hop', 'indie', 'pop', 'trap'},
#  {'australian', 'dream', 'indie', 'pop'},
#  {'bubblegrunge', 'indie', 'minneapolis', 'pop', 'rock'},
#  {'edm', 'house', 'progressive', 'trance', 'uplifting'},
#  {'electropop', 'indie', 'modern', 'pop', 'poptimism', 'rock'},
#  {'chicago', 'conscious', 'hip', 'hop', 'political', 'pop', 'rap', 'southern'},
#  {'electropop', 'indie'},
#  {'aussietronica'},
#  {'adelaide', 'australian', 'garage', 'indie', 'psych', 'punk'},
#  {'filter', 'house', 'indie', 'soul'},
#  {'christian', 'indie', 'indiecoustica', 'ok'},
#  {'alternative',
#   'dance',
#   'electrofox',
#   'indie',
#   'metropopolis',
#   'northamptonshire',
#   'pop',
#   'poptimism',
#   'shimmer'},
#  {'dfw', 'melodic', 'rap'},
#  {'australian', 'fremantle', 'indie', 'metropopolis', 'perth', 'pop'},
#  {'ambeat'},
#  {'ambeat'},
#  {'ambeat', 'chillhop'},
#  {'rap', 'underground'},
#  {'ambeat'},
#  {'beats', 'focus'},
#  {'aussie',
#   'australian',
#   'emo',
#   'hardcore',
#   'indie',
#   'newcastle',
#   'nsw',
#   'post'},
#  {'electropop', 'etherpop', 'folk', 'indie', 'pop', 'rock'},
#  {'australian', 'indie', 'pop'},
#  {'bass', 'beats', 'future', 'kawaii', 'lofi'},
#  {'dream',
#   'electropop',
#   'indie',
#   'indietronica',
#   'modern',
#   'pop',
#   'poptimism',
#   'soul',
#   'vapor'},
#  {'alternative', 'dance', 'indie', 'modern', 'new', 'punk', 'rave', 'rock'},
#  {'australian', 'indie', 'pop'},
#  {'chillhop', 'downtempo', 'japanese', 'jazz', 'rap'},
#  {'hawaiian', 'hip', 'hop'},
#  {'alternative', 'bass', 'modern', 'rock', 'trap', 'traprun'},
#  {'australian', 'fremantle', 'garage', 'indie', 'perth', 'punk', 'rock'},
#  {'australian', 'neo', 'psych', 'psychedelic'},
#  {'bc', 'canadian', 'indie', 'kelowna', 'vancouver'},
#  {'electropop', 'pop'},
#  {'australian', 'indie', 'rock'},
#  {'australian', 'fusion', 'jazz', 'reggae', 'ska'},
#  {'and',
#   'art',
#   'brooklyn',
#   'chamber',
#   'folk',
#   'freak',
#   'holler',
#   'indie',
#   'pop',
#   'rock',
#   'room',
#   'small',
#   'stomp'},
#  {'electronica', 'french', 'indie', 'indietronica', 'new', 'pop', 'touch'},
#  {'canadian', 'indie', 'rock', 'vancouver'},
#  {'anthem', 'folk', 'indie', 'soul', 'vapor'},
#  {'adelaide', 'indie'},
#  {'aussie', 'australian', 'drill', 'trap'},
#  {'aussie', 'drill'},
#  {'ambient', 'american', 'compositional', 'post', 'rock'},
#  {'art', 'band', 'folk', 'freak', 'indie', 'one', 'person', 'pop', 'rock'},
#  {'nz', 'pop'},
#  {'edm', 'indonesian'},
#  {'indie', 'indonesian'},
#  {'french', 'new', 'touch'},
#  {'alternative', 'australian', 'pop'},
#  {'indie', 'minneapolis'},
#  {'americana', 'and', 'deep', 'holler', 'indiecoustica', 'new', 'stomp'},
#  {'alternative', 'blues', 'garage', 'hard', 'modern', 'punk', 'rock', 'roots'},
#  {'downtempo',
#   'electronica',
#   'hop',
#   'jazz',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'trip'},
#  {'electronica', 'future', 'garage', 'indie', 'soul'},
#  {'alternative',
#   'art',
#   'dance',
#   'electronica',
#   'experimental',
#   'hop',
#   'icelandic',
#   'metropopolis',
#   'permanent',
#   'pop',
#   'trip',
#   'vocal',
#   'wave'},
#  {'bass', 'chillwave', 'electronica', 'microhouse', 'music', 'ninja', 'wonky'},
#  {'afrofuturism',
#   'alternative',
#   'art',
#   'escape',
#   'indie',
#   'la',
#   'pop',
#   'rb',
#   'room',
#   'soul'},
#  {'indie', 'oc'},
#  {'alternative', 'indie', 'rb'},
#  {'hip', 'hop', 'pittsburgh', 'rap'},
#  {'art', 'chillwave', 'electronica', 'indie', 'pop', 'soul'},
#  {'dancehall', 'fusion', 'lovers', 'modern', 'reggae', 'rock', 'roots'},
#  {'dream', 'indie', 'metropopolis', 'pop', 'shoegaze'},
#  {'indie', 'tassie'},
#  {'alternative',
#   'blues',
#   'desert',
#   'metal',
#   'modern',
#   'nu',
#   'palm',
#   'rock',
#   'scene',
#   'stoner'},
#  {'alternative',
#   'dance',
#   'francais',
#   'independant',
#   'indie',
#   'modern',
#   'new',
#   'pop',
#   'punk',
#   'rave',
#   'rock'},
#  {'auckland',
#   'electropop',
#   'etherpop',
#   'house',
#   'indie',
#   'indietronica',
#   'metropopolis',
#   'nz',
#   'pop',
#   'poptimism',
#   'shimmer',
#   'soul',
#   'tropical',
#   'vapor'},
#  {'german', 'hip', 'hop', 'pop', 'rap'},
#  {'german', 'pop', 'rb'},
#  {'cafe', 'indie', 'indiecoustica', 'pop'},
#  {'alternative', 'chill', 'indie', 'nyc', 'pop', 'rb', 'soul', 'vapor'},
#  {'anthem', 'folk', 'indie'},
#  {'alternative', 'indie', 'minneapolis', 'modern', 'pop', 'poptimism', 'rock'},
#  {'electropop', 'indie', 'pop', 'poptimism', 'soul', 'vapor'},
#  {'modern', 'punk', 'ska'},
#  {'adelaide', 'indie'},
#  {'australian', 'indie', 'pop'},
#  {'chillstep', 'twitch', 'vapor'},
#  {'nz', 'pop'},
#  {'australian', 'garage', 'indie', 'pop', 'punk'},
#  {'german', 'indie', 'pop', 'rock'},
#  {'alternative', 'bedroom', 'cafe', 'indie', 'pop', 'rb'},
#  {'alternative', 'escape', 'indie', 'neo', 'rb', 'room', 'soul'},
#  {'atl', 'hip', 'hop', 'pop', 'rap'},
#  {'alternative', 'dmv', 'hip', 'hop', 'pop', 'rap', 'sudanese'},
#  {'alternative', 'dance', 'electronica', 'new', 'punk', 'rave'},
#  {'australian', 'indie', 'rock'},
#  {'alternative', 'and', 'folk', 'holler', 'indie', 'modern', 'rock', 'stomp'},
#  {'indie', 'seattle'},
#  {'dance',
#   'electropop',
#   'escape',
#   'pop',
#   'post',
#   'queen',
#   'room',
#   'teen',
#   'trap'},
#  {'indie', 'nashville'},
#  {'reggae', 'rock'},
#  {'band', 'jam', 'jamtronica', 'livetronica'},
#  {'indie', 'metropopolis', 'nottingham'},
#  {'art',
#   'canadian',
#   'chillwave',
#   'edmonton',
#   'electropop',
#   'grave',
#   'indie',
#   'indietronica',
#   'metropopolis',
#   'pop',
#   'shimmer',
#   'soul',
#   'vapor',
#   'wave'},
#  {'bass', 'downtempo'},
#  {'indie', 'jazz', 'pop', 'soul'},
#  {'alternative', 'british', 'pop', 'soul', 'uk'},
#  {'australian', 'edm', 'electropop', 'indietronica'},
#  {'downtempo', 'electronica', 'hop', 'jazz', 'nu', 'trip'},
#  {'birmingham', 'hip', 'hop'},
#  {'indie', 'vienna'},
#  {'baroque', 'brooklyn', 'indie', 'pop'},
#  {'and',
#   'folk',
#   'holler',
#   'indie',
#   'metropopolis',
#   'pop',
#   'shimmer',
#   'stomp',
#   'whittle'},
#  {'indie', 'jacksonville', 'modern', 'rock'},
#  {'and', 'folk', 'freak', 'holler', 'indie', 'philly', 'stomp'},
#  {'alternative', 'modern', 'pop', 'rock'},
#  {'hip', 'hop', 'underground'},
#  {'french',
#   'indie',
#   'indietronica',
#   'new',
#   'pop',
#   'soul',
#   'synthpop',
#   'touch'},
#  {'danish', 'jazz', 'modern'},
#  {'electra'},
#  {'fusion', 'reggae', 'rock'},
#  {'electropop', 'metropopolis', 'pop', 'vapor'},
#  {'french', 'new', 'touch'},
#  {'deep', 'hip', 'hop', 'indie', 'pop', 'rap', 'underground'},
#  {'beats', 'chillhop', 'lofi'},
#  {'alternative', 'birmingham', 'english', 'indie', 'modern', 'rock'},
#  {'pop', 'rap'},
#  {'alternative',
#   'beat',
#   'big',
#   'electronica',
#   'hip',
#   'hop',
#   'jazz',
#   'jazztronica',
#   'ninja',
#   'nu',
#   'turntablism'},
#  {'indie', 'pop', 'rock'},
#  {'australian', 'indie', 'pop', 'soul'},
#  {'cyberpunk', 'synthwave'},
#  {'popwave', 'spacewave', 'synthwave'},
#  {'alternative', 'australian', 'indie', 'pop', 'shimmer'},
#  {'alternative',
#   'beat',
#   'big',
#   'dance',
#   'downtempo',
#   'electronica',
#   'electropop',
#   'hop',
#   'trip'},
#  {'indie', 'nyc', 'pop'},
#  {'comic', 'conscious', 'hip', 'hop'},
#  {'australian', 'dance'},
#  {'australian', 'brisbane', 'garage', 'indie', 'punk'},
#  {'alternative',
#   'escape',
#   'hip',
#   'hop',
#   'indie',
#   'queen',
#   'room',
#   'soul',
#   'trap',
#   'uk'},
#  {'chicago',
#   'classic',
#   'funk',
#   'memphis',
#   'motown',
#   'quiet',
#   'soul',
#   'southern',
#   'storm'},
#  {'alternative', 'cali', 'modern', 'rap', 'rock'},
#  {'bounce',
#   'escape',
#   'hip',
#   'hop',
#   'lgbtq',
#   'new',
#   'orleans',
#   'queen',
#   'rap',
#   'room',
#   'trap'},
#  {'dance',
#   'escape',
#   'hip',
#   'hop',
#   'minnesota',
#   'pop',
#   'queen',
#   'rap',
#   'room',
#   'trap'},
#  {'retro', 'soul'},
#  {'french', 'indie', 'indietronica', 'new', 'pop', 'touch'},
#  {'mpb', 'nova'},
#  {'modern', 'rock', 'spanish'},
#  {'alternative', 'dance', 'disco', 'indie', 'new', 'nu', 'rave', 'soul'},
#  {'la', 'pop'},
#  {'dance', 'edm', 'electropop', 'house', 'pop', 'tropical'},
#  {'dance', 'electropop', 'pop', 'post', 'teen', 'viral'},
#  {'ambient',
#   'british',
#   'compositional',
#   'contemporary',
#   'electronica',
#   'jazz',
#   'new',
#   'nu',
#   'quartet',
#   'tribe'},
#  {'abstract', 'comic', 'hip', 'hop', 'modern', 'pop', 'rap', 'rock'},
#  {'alternative',
#   'aussietronica',
#   'electropop',
#   'indie',
#   'rb',
#   'soul',
#   'vapor'},
#  {'alternative', 'dance', 'soul', 'vapor'},
#  {'australian', 'indie'},
#  {'australian', 'trap'},
#  {'francais', 'independant', 'rock'},
#  {'area',
#   'art',
#   'bay',
#   'chillwave',
#   'folk',
#   'indie',
#   'oakland',
#   'pop',
#   'rock',
#   'room',
#   'small'},
#  {'art', 'bubblegrunge', 'eugene', 'indie', 'philly', 'pop', 'rock'},
#  {'australian', 'indie', 'pop'},
#  {'fusion', 'reggae', 'rock'},
#  {'austindie', 'pop', 'soul'},
#  {'fl', 'indie', 'petersburg', 'st'},
#  {'coast', 'gangster', 'hyphy', 'rap', 'trap', 'west'},
#  {'arabic', 'french', 'jazz', 'trumpet'},
#  {'aussietronica',
#   'dance',
#   'edm',
#   'gauze',
#   'house',
#   'indie',
#   'pop',
#   'soul',
#   'tropical'},
#  {'candy',
#   'dance',
#   'electropop',
#   'metropopolis',
#   'pop',
#   'swedish',
#   'synthpop'},
#  {'nz', 'pop'},
#  {'big',
#   'dance',
#   'edm',
#   'electro',
#   'house',
#   'pop',
#   'progressive',
#   'room',
#   'trance',
#   'tropical',
#   'uplifting'},
#  {'dream', 'korean', 'pop'},
#  {'alternative', 'indie', 'la', 'modern', 'pop', 'poptimism', 'rock'},
#  {'cafe', 'indie', 'pop'},
#  {'instrumental', 'rock'},
#  {'australian', 'electropop', 'indie', 'soul', 'vapor'},
#  {'ambient',
#   'electronic',
#   'electronica',
#   'french',
#   'hamburg',
#   'microhouse',
#   'minimal',
#   'new',
#   'organic',
#   'pop',
#   'techno',
#   'touch'},
#  {'australian', 'hip', 'hop'},
#  {'candy', 'emo', 'pixie', 'pop', 'punk'},
#  {'disco', 'filter', 'house', 'vocal'},
#  {'classical', 'jazz', 'performance', 'piano', 'turkish'},
#  {'classical', 'performance', 'taiwan'},
#  {'australian', 'electropop'},
#  {'pop', 'vapor'},
#  {'bedroom', 'bubblegrunge', 'indie', 'pop'},
#  {'australian', 'fusion', 'reggae'},
#  {'indie', 'jazz', 'soul'},
#  {'alternative',
#   'canadian',
#   'dance',
#   'electropop',
#   'indie',
#   'indietronica',
#   'metropopolis',
#   'modern',
#   'neo',
#   'new',
#   'pop',
#   'punk',
#   'rave',
#   'rock',
#   'shimmer',
#   'synthpop'},
#  {'chillwave', 'indie', 'jazz', 'wonky'},
#  {'australian', 'indie', 'rock'},
#  {'alternative',
#   'atl',
#   'conscious',
#   'dirty',
#   'gangster',
#   'hardcore',
#   'hip',
#   'hop',
#   'rap',
#   'south',
#   'southern',
#   'trap'},
#  {'alternative',
#   'bronx',
#   'coast',
#   'conscious',
#   'east',
#   'gangster',
#   'hardcore',
#   'hip',
#   'hop',
#   'old',
#   'political',
#   'rap',
#   'school',
#   'turntablism'},
#  {'alternative',
#   'chicago',
#   'conscious',
#   'gangster',
#   'hardcore',
#   'hip',
#   'hop',
#   'neo',
#   'political',
#   'rap',
#   'soul',
#   'southern'},
#  {'ambeat', 'jazz', 'rap', 'underground'},
#  {'electropop', 'indie', 'poptimism'},
#  {'art', 'bubblegrunge', 'folk', 'indie', 'pop', 'rock'},
#  {'alternative', 'escape', 'experimental', 'hip', 'hop', 'industrial', 'room'},
#  {'art', 'chamber', 'pop', 'psych'},
#  {'chamber',
#   'contemporary',
#   'folk',
#   'fourth',
#   'indie',
#   'jazz',
#   'psych',
#   'uk',
#   'world'},
#  {'afrobeat', 'afropop', 'blues', 'desert', 'malian', 'mande', 'pop', 'world'},
#  {'blues',
#   'country',
#   'folk',
#   'gold',
#   'mellow',
#   'piedmont',
#   'rock',
#   'roots',
#   'singer',
#   'songwriter',
#   'traditional'},
#  {'americana',
#   'and',
#   'canadian',
#   'folk',
#   'holler',
#   'indie',
#   'new',
#   'pop',
#   'stomp'},
#  {'german', 'house'},
#  {'dance', 'edm', 'electropop', 'house', 'pop', 'tropical'},
#  {'electropop', 'indie', 'pop'},
#  {'alternative',
#   'auckland',
#   'dance',
#   'electropop',
#   'indie',
#   'indietronica',
#   'kiwi',
#   'metropopolis',
#   'modern',
#   'pop',
#   'rock',
#   'shimmer'},
#  {'clarinet', 'dixieland', 'jazz', 'new', 'orleans'},
#  {'irish', 'neo', 'traditional'},
#  {'brisbane', 'indie'},
#  {'australian', 'garage', 'punk'},
#  {'downtempo', 'electronica', 'hop', 'livetronica', 'trip'},
#  {'australian', 'hip', 'hop'},
#  {'alternative', 'dance', 'electronica'},
#  {'alternative', 'country', 'queer'},
#  {'chanson',
#   'francaise',
#   'french',
#   'indie',
#   'indietronica',
#   'nouvelle',
#   'pop',
#   'rock'},
#  {'belgian', 'francaise', 'pop', 'variete'},
#  {'classical', 'neo'},
#  {'electronic', 'electronica', 'hamburg', 'microhouse', 'minimal', 'techno'},
#  {'american', 'asian', 'battle', 'hip', 'hop', 'k', 'rap'},
#  {'dance',
#   'deep',
#   'disco',
#   'edm',
#   'house',
#   'pop',
#   'progressive',
#   'tech',
#   'tropical'},
#  {'neo', 'psychedelic'},
#  {'ambient',
#   'bow',
#   'classical',
#   'compositional',
#   'darkwave',
#   'icelandic',
#   'neo',
#   'neoclassical',
#   'pop'},
#  {'complextro', 'edm', 'electro', 'filthstep', 'glitch', 'house'},
#  {'and', 'holler', 'indie', 'pop', 'portland', 'stomp'},
#  {'indie', 'maine', 'pop', 'rock', 'singer', 'songwriter'},
#  {'dark', 'drill', 'hip', 'hop', 'miami', 'rap', 'trap', 'underground'},
#  {'hip', 'hop', 'trap', 'underground'},
#  {'fusion', 'reggae'},
#  {'pop', 'post', 'teen'},
#  {'indie', 'scottish'},
#  {'alternative',
#   'chillwave',
#   'dance',
#   'dream',
#   'electropop',
#   'indie',
#   'indietronica',
#   'metropopolis',
#   'modern',
#   'pop',
#   'rock',
#   'shimmer',
#   'soul',
#   'vapor'},
#  {'art', 'dance', 'electropop', 'indie', 'pop', 'swedish'},
#  {'garage', 'indie', 'modern', 'pop', 'rock', 'soul', 'vapor'}]

# %%
type(genres_set)
# Out:
# list

# %%
type(genres_set[0])
# Out:
# set

# %%
type(list(genres_set[0]))
# Out:
# list

# %%
all_genres = []

for genre in genres_set:
    all_genres.append(list(genre))

all_genres
# Out:
# [['alternative',
#   'modern',
#   'indie',
#   'garage',
#   'revival',
#   'supergroup',
#   'blues',
#   'rock'],
#  ['vapor', 'twitch'],
#  ['alternative', 'pop', 'australian'],
#  ['fidget', 'house', 'bass', 'australian'],
#  ['intelligent',
#   'dance',
#   'chillwave',
#   'downtempo',
#   'electronica',
#   'indietronica',
#   'music'],
#  ['downtempo', 'bass'],
#  ['indie', 'pop'],
#  ['modern',
#   'alternative',
#   'emo',
#   'punk',
#   'rock',
#   'pixie',
#   'pop',
#   'electropop'],
#  ['pop', 'australian'],
#  ['pop', 'uk'],
#  ['alternative', 'pop', 'uk'],
#  ['alternative', 'indie', 'uk', 'soul', 'pop'],
#  ['urban', 'post', 'rb', 'teen', 'dance', 'contemporary', 'hip', 'rap', 'pop'],
#  ['hop', 'christian', 'houston', 'hip', 'rap'],
#  ['bedroom', 'indie', 'pop', 'boston'],
#  ['jawaiian', 'rock', 'reggae'],
#  ['reggae', 'fusion', 'rock'],
#  ['aussietronica'],
#  ['aussietronica'],
#  ['alternative',
#   'modern',
#   'indie',
#   'hop',
#   'room',
#   'escape',
#   'soul',
#   'hip',
#   'canadian',
#   'funk',
#   'jazz'],
#  ['indie', 'sydney'],
#  ['la', 'pop'],
#  ['psychedelic', 'punk', 'garage', 'australian', 'neo', 'psych'],
#  ['big',
#   'nu',
#   'trip',
#   'jazztronica',
#   'hop',
#   'ninja',
#   'downtempo',
#   'beat',
#   'electronica',
#   'jazz'],
#  ['indie', 'anthem', 'brisbane', 'folk'],
#  ['indie', 'pop', 'danish'],
#  ['melancholia',
#   'chamber',
#   'indie',
#   'art',
#   'baroque',
#   'freak',
#   'holler',
#   'stomp',
#   'chicago',
#   'rock',
#   'folk',
#   'pop',
#   'and'],
#  ['punk', 'pop', 'socal'],
#  ['poptimism',
#   'tropical',
#   'indie',
#   'dance',
#   'house',
#   'edm',
#   'electropop',
#   'pop'],
#  ['deep', 'tropical', 'house', 'edm', 'pop'],
#  ['deep', 'new', 'americana', 'indie', 'retro', 'soul', 'funk', 'folk'],
#  ['big',
#   'tropical',
#   'house',
#   'dance',
#   'edm',
#   'room',
#   'progressive',
#   'electro',
#   'pop',
#   'electropop'],
#  ['alternative', 'pop', 'australian'],
#  ['punk', 'indie', 'garage', 'rock', 'australian'],
#  ['modern', 'indie', 'bedroom', 'rock', 'oakland', 'pop'],
#  ['alternative',
#   'new',
#   'punk',
#   'dance',
#   'room',
#   'rave',
#   'escape',
#   'electropop'],
#  ['alternative',
#   'vapor',
#   'tropical',
#   'twitch',
#   'rb',
#   'indie',
#   'house',
#   'edm',
#   'soul',
#   'electropop'],
#  ['alternative', 'rb', 'indie', 'contemporary', 'soul', 'uk', 'gauze', 'pop'],
#  ['post',
#   'math',
#   'indie',
#   'rock',
#   'asian',
#   'taiwan',
#   'instrumental',
#   'southeast'],
#  ['hop', 'conscious', 'hip', 'dmv', 'rap', 'pop'],
#  ['indie', 'brisbane', 'rock', 'australian'],
#  ['trap', 'hop', 'hip', 'australian'],
#  ['trap', 'australian'],
#  ['deep', 'tropical', 'house', 'dance', 'edm', 'electropop', 'pop'],
#  ['hop', 'hip', 'australian'],
#  ['alternative', 'modern', 'emo', 'rock', 'pixie', 'british', 'pop'],
#  ['boston', 'mellow', 'rock', 'neo', 'pop'],
#  ['tropical', 'house', 'progressive', 'gauze', 'pop'],
#  ['shimmer', 'art', 'chillwave', 'metropopolis', 'pop', 'electropop'],
#  ['indie', 'kent'],
#  ['vapor', 'pop'],
#  ['indie', 'anthem', 'folk', 'australian'],
#  ['house', 'uk'],
#  ['fusion', 'contemporary', 'progressive', 'rock', 'funk', 'jazz'],
#  ['alternative', 'vapor', 'rb', 'indie', 'dance', 'edm', 'soul', 'uk', 'pop'],
#  ['bedroom', 'indie', 'pop', 'boston'],
#  ['indie', 'hop', 'hip', 'australian', 'trap', 'pop'],
#  ['indie', 'dream', 'pop', 'australian'],
#  ['indie', 'minneapolis', 'rock', 'pop', 'bubblegrunge'],
#  ['house', 'uplifting', 'edm', 'trance', 'progressive'],
#  ['modern', 'poptimism', 'indie', 'rock', 'pop', 'electropop'],
#  ['hop', 'chicago', 'conscious', 'hip', 'rap', 'political', 'southern', 'pop'],
#  ['indie', 'electropop'],
#  ['aussietronica'],
#  ['adelaide', 'indie', 'punk', 'garage', 'australian', 'psych'],
#  ['indie', 'house', 'filter', 'soul'],
#  ['indie', 'ok', 'indiecoustica', 'christian'],
#  ['alternative',
#   'electrofox',
#   'poptimism',
#   'northamptonshire',
#   'shimmer',
#   'indie',
#   'dance',
#   'metropopolis',
#   'pop'],
#  ['rap', 'melodic', 'dfw'],
#  ['indie', 'perth', 'fremantle', 'australian', 'metropopolis', 'pop'],
#  ['ambeat'],
#  ['ambeat'],
#  ['chillhop', 'ambeat'],
#  ['rap', 'underground'],
#  ['ambeat'],
#  ['beats', 'focus'],
#  ['post',
#   'emo',
#   'indie',
#   'aussie',
#   'nsw',
#   'australian',
#   'hardcore',
#   'newcastle'],
#  ['indie', 'etherpop', 'electropop', 'rock', 'folk', 'pop'],
#  ['indie', 'pop', 'australian'],
#  ['bass', 'lofi', 'kawaii', 'future', 'beats'],
#  ['modern',
#   'vapor',
#   'poptimism',
#   'indie',
#   'dream',
#   'indietronica',
#   'soul',
#   'electropop',
#   'pop'],
#  ['alternative', 'modern', 'new', 'punk', 'dance', 'indie', 'rave', 'rock'],
#  ['indie', 'pop', 'australian'],
#  ['downtempo', 'japanese', 'rap', 'jazz', 'chillhop'],
#  ['hop', 'hip', 'hawaiian'],
#  ['modern', 'alternative', 'bass', 'rock', 'trap', 'traprun'],
#  ['punk', 'indie', 'garage', 'perth', 'fremantle', 'rock', 'australian'],
#  ['psychedelic', 'neo', 'australian', 'psych'],
#  ['vancouver', 'indie', 'kelowna', 'bc', 'canadian'],
#  ['pop', 'electropop'],
#  ['indie', 'rock', 'australian'],
#  ['fusion', 'ska', 'australian', 'reggae', 'jazz'],
#  ['chamber',
#   'brooklyn',
#   'small',
#   'indie',
#   'art',
#   'freak',
#   'room',
#   'stomp',
#   'holler',
#   'rock',
#   'folk',
#   'pop',
#   'and'],
#  ['new', 'indie', 'french', 'indietronica', 'touch', 'electronica', 'pop'],
#  ['indie', 'vancouver', 'rock', 'canadian'],
#  ['vapor', 'indie', 'soul', 'anthem', 'folk'],
#  ['indie', 'adelaide'],
#  ['drill', 'trap', 'australian', 'aussie'],
#  ['drill', 'aussie'],
#  ['compositional', 'post', 'rock', 'american', 'ambient'],
#  ['person', 'indie', 'art', 'freak', 'band', 'rock', 'one', 'folk', 'pop'],
#  ['nz', 'pop'],
#  ['indonesian', 'edm'],
#  ['indie', 'indonesian'],
#  ['french', 'new', 'touch'],
#  ['alternative', 'pop', 'australian'],
#  ['indie', 'minneapolis'],
#  ['deep', 'new', 'americana', 'holler', 'stomp', 'and', 'indiecoustica'],
#  ['alternative', 'modern', 'punk', 'garage', 'blues', 'rock', 'roots', 'hard'],
#  ['nu',
#   'trip',
#   'jazztronica',
#   'hop',
#   'ninja',
#   'downtempo',
#   'electronica',
#   'jazz'],
#  ['indie', 'garage', 'soul', 'electronica', 'future'],
#  ['alternative',
#   'trip',
#   'permanent',
#   'dance',
#   'art',
#   'hop',
#   'wave',
#   'icelandic',
#   'vocal',
#   'experimental',
#   'electronica',
#   'metropopolis',
#   'pop'],
#  ['bass', 'chillwave', 'ninja', 'electronica', 'microhouse', 'wonky', 'music'],
#  ['alternative',
#   'rb',
#   'indie',
#   'art',
#   'la',
#   'room',
#   'soul',
#   'afrofuturism',
#   'escape',
#   'pop'],
#  ['indie', 'oc'],
#  ['alternative', 'indie', 'rb'],
#  ['rap', 'hop', 'hip', 'pittsburgh'],
#  ['indie', 'art', 'chillwave', 'soul', 'electronica', 'pop'],
#  ['modern', 'fusion', 'dancehall', 'rock', 'reggae', 'roots', 'lovers'],
#  ['indie', 'dream', 'shoegaze', 'metropopolis', 'pop'],
#  ['indie', 'tassie'],
#  ['alternative',
#   'modern',
#   'nu',
#   'stoner',
#   'scene',
#   'metal',
#   'blues',
#   'desert',
#   'rock',
#   'palm'],
#  ['alternative',
#   'modern',
#   'new',
#   'indie',
#   'dance',
#   'punk',
#   'rave',
#   'rock',
#   'francais',
#   'independant',
#   'pop'],
#  ['vapor',
#   'poptimism',
#   'tropical',
#   'shimmer',
#   'indie',
#   'house',
#   'auckland',
#   'indietronica',
#   'soul',
#   'electropop',
#   'etherpop',
#   'metropopolis',
#   'nz',
#   'pop'],
#  ['hop', 'hip', 'german', 'rap', 'pop'],
#  ['pop', 'german', 'rb'],
#  ['indie', 'pop', 'indiecoustica', 'cafe'],
#  ['alternative', 'vapor', 'rb', 'indie', 'chill', 'soul', 'nyc', 'pop'],
#  ['indie', 'anthem', 'folk'],
#  ['modern', 'alternative', 'poptimism', 'indie', 'minneapolis', 'rock', 'pop'],
#  ['vapor', 'poptimism', 'indie', 'soul', 'electropop', 'pop'],
#  ['modern', 'ska', 'punk'],
#  ['indie', 'adelaide'],
#  ['indie', 'pop', 'australian'],
#  ['chillstep', 'vapor', 'twitch'],
#  ['nz', 'pop'],
#  ['punk', 'indie', 'garage', 'australian', 'pop'],
#  ['indie', 'rock', 'pop', 'german'],
#  ['alternative', 'rb', 'indie', 'cafe', 'bedroom', 'pop'],
#  ['alternative', 'rb', 'indie', 'neo', 'room', 'soul', 'escape'],
#  ['hop', 'hip', 'atl', 'rap', 'pop'],
#  ['alternative', 'hop', 'sudanese', 'hip', 'dmv', 'rap', 'pop'],
#  ['alternative', 'new', 'punk', 'dance', 'rave', 'electronica'],
#  ['indie', 'rock', 'australian'],
#  ['alternative', 'modern', 'indie', 'holler', 'stomp', 'rock', 'folk', 'and'],
#  ['indie', 'seattle'],
#  ['post',
#   'queen',
#   'teen',
#   'dance',
#   'room',
#   'trap',
#   'pop',
#   'escape',
#   'electropop'],
#  ['indie', 'nashville'],
#  ['reggae', 'rock'],
#  ['jamtronica', 'band', 'jam', 'livetronica'],
#  ['indie', 'nottingham', 'metropopolis'],
#  ['vapor',
#   'shimmer',
#   'indie',
#   'art',
#   'grave',
#   'chillwave',
#   'indietronica',
#   'edmonton',
#   'wave',
#   'soul',
#   'canadian',
#   'metropopolis',
#   'pop',
#   'electropop'],
#  ['downtempo', 'bass'],
#  ['indie', 'jazz', 'pop', 'soul'],
#  ['alternative', 'uk', 'soul', 'british', 'pop'],
#  ['indietronica', 'electropop', 'australian', 'edm'],
#  ['nu', 'trip', 'hop', 'downtempo', 'electronica', 'jazz'],
#  ['birmingham', 'hop', 'hip'],
#  ['indie', 'vienna'],
#  ['indie', 'brooklyn', 'baroque', 'pop'],
#  ['whittle',
#   'shimmer',
#   'indie',
#   'holler',
#   'stomp',
#   'metropopolis',
#   'folk',
#   'pop',
#   'and'],
#  ['indie', 'jacksonville', 'rock', 'modern'],
#  ['indie', 'freak', 'holler', 'stomp', 'philly', 'folk', 'and'],
#  ['alternative', 'rock', 'pop', 'modern'],
#  ['hop', 'hip', 'underground'],
#  ['synthpop',
#   'new',
#   'indie',
#   'french',
#   'touch',
#   'soul',
#   'pop',
#   'indietronica'],
#  ['modern', 'jazz', 'danish'],
#  ['electra'],
#  ['reggae', 'fusion', 'rock'],
#  ['vapor', 'electropop', 'metropopolis', 'pop'],
#  ['french', 'new', 'touch'],
#  ['deep', 'indie', 'hop', 'hip', 'rap', 'pop', 'underground'],
#  ['beats', 'chillhop', 'lofi'],
#  ['birmingham', 'modern', 'alternative', 'indie', 'rock', 'english'],
#  ['rap', 'pop'],
#  ['alternative',
#   'big',
#   'nu',
#   'jazztronica',
#   'hop',
#   'ninja',
#   'beat',
#   'hip',
#   'electronica',
#   'turntablism',
#   'jazz'],
#  ['indie', 'rock', 'pop'],
#  ['indie', 'pop', 'australian', 'soul'],
#  ['cyberpunk', 'synthwave'],
#  ['spacewave', 'popwave', 'synthwave'],
#  ['alternative', 'shimmer', 'indie', 'australian', 'pop'],
#  ['alternative',
#   'big',
#   'trip',
#   'dance',
#   'hop',
#   'downtempo',
#   'beat',
#   'electronica',
#   'electropop'],
#  ['indie', 'nyc', 'pop'],
#  ['hop', 'conscious', 'hip', 'comic'],
#  ['dance', 'australian'],
#  ['punk', 'indie', 'garage', 'brisbane', 'australian'],
#  ['alternative',
#   'queen',
#   'indie',
#   'hop',
#   'soul',
#   'room',
#   'uk',
#   'hip',
#   'trap',
#   'escape'],
#  ['motown',
#   'quiet',
#   'soul',
#   'chicago',
#   'southern',
#   'storm',
#   'funk',
#   'memphis',
#   'classic'],
#  ['cali', 'alternative', 'modern', 'rock', 'rap'],
#  ['bounce',
#   'new',
#   'queen',
#   'hop',
#   'room',
#   'hip',
#   'lgbtq',
#   'orleans',
#   'rap',
#   'trap',
#   'escape'],
#  ['minnesota',
#   'queen',
#   'dance',
#   'hop',
#   'room',
#   'hip',
#   'rap',
#   'trap',
#   'escape',
#   'pop'],
#  ['retro', 'soul'],
#  ['new', 'indie', 'french', 'touch', 'pop', 'indietronica'],
#  ['mpb', 'nova'],
#  ['modern', 'rock', 'spanish'],
#  ['alternative', 'nu', 'new', 'disco', 'indie', 'dance', 'soul', 'rave'],
#  ['la', 'pop'],
#  ['tropical', 'dance', 'house', 'edm', 'electropop', 'pop'],
#  ['post', 'teen', 'dance', 'viral', 'pop', 'electropop'],
#  ['compositional',
#   'new',
#   'nu',
#   'contemporary',
#   'tribe',
#   'quartet',
#   'electronica',
#   'ambient',
#   'british',
#   'jazz'],
#  ['modern', 'hop', 'hip', 'rock', 'comic', 'rap', 'pop', 'abstract'],
#  ['alternative',
#   'aussietronica',
#   'vapor',
#   'rb',
#   'indie',
#   'soul',
#   'electropop'],
#  ['alternative', 'dance', 'vapor', 'soul'],
#  ['indie', 'australian'],
#  ['trap', 'australian'],
#  ['francais', 'independant', 'rock'],
#  ['small',
#   'indie',
#   'art',
#   'chillwave',
#   'room',
#   'area',
#   'rock',
#   'oakland',
#   'folk',
#   'pop',
#   'bay'],
#  ['indie', 'art', 'eugene', 'rock', 'philly', 'pop', 'bubblegrunge'],
#  ['indie', 'pop', 'australian'],
#  ['reggae', 'fusion', 'rock'],
#  ['austindie', 'pop', 'soul'],
#  ['petersburg', 'indie', 'fl', 'st'],
#  ['hyphy', 'coast', 'trap', 'rap', 'gangster', 'west'],
#  ['french', 'arabic', 'jazz', 'trumpet'],
#  ['aussietronica',
#   'tropical',
#   'indie',
#   'house',
#   'dance',
#   'edm',
#   'soul',
#   'gauze',
#   'pop'],
#  ['synthpop',
#   'swedish',
#   'dance',
#   'candy',
#   'metropopolis',
#   'pop',
#   'electropop'],
#  ['nz', 'pop'],
#  ['big',
#   'tropical',
#   'house',
#   'dance',
#   'uplifting',
#   'edm',
#   'room',
#   'progressive',
#   'trance',
#   'electro',
#   'pop'],
#  ['dream', 'korean', 'pop'],
#  ['modern', 'alternative', 'poptimism', 'indie', 'la', 'rock', 'pop'],
#  ['indie', 'pop', 'cafe'],
#  ['rock', 'instrumental'],
#  ['vapor', 'indie', 'soul', 'australian', 'electropop'],
#  ['organic',
#   'new',
#   'french',
#   'minimal',
#   'touch',
#   'hamburg',
#   'techno',
#   'microhouse',
#   'electronica',
#   'electronic',
#   'ambient',
#   'pop'],
#  ['hop', 'hip', 'australian'],
#  ['emo', 'punk', 'candy', 'pixie', 'pop'],
#  ['house', 'disco', 'vocal', 'filter'],
#  ['classical', 'performance', 'jazz', 'turkish', 'piano'],
#  ['performance', 'taiwan', 'classical'],
#  ['electropop', 'australian'],
#  ['vapor', 'pop'],
#  ['bedroom', 'indie', 'pop', 'bubblegrunge'],
#  ['reggae', 'fusion', 'australian'],
#  ['indie', 'jazz', 'soul'],
#  ['alternative',
#   'modern',
#   'synthpop',
#   'new',
#   'shimmer',
#   'indie',
#   'dance',
#   'punk',
#   'indietronica',
#   'rave',
#   'rock',
#   'canadian',
#   'metropopolis',
#   'pop',
#   'neo',
#   'electropop'],
#  ['indie', 'wonky', 'chillwave', 'jazz'],
#  ['indie', 'rock', 'australian'],
#  ['alternative',
#   'hop',
#   'southern',
#   'south',
#   'trap',
#   'conscious',
#   'hip',
#   'atl',
#   'hardcore',
#   'rap',
#   'gangster',
#   'dirty'],
#  ['alternative',
#   'coast',
#   'hop',
#   'bronx',
#   'east',
#   'school',
#   'conscious',
#   'hip',
#   'turntablism',
#   'rap',
#   'gangster',
#   'hardcore',
#   'political',
#   'old'],
#  ['alternative',
#   'hop',
#   'southern',
#   'neo',
#   'soul',
#   'chicago',
#   'conscious',
#   'hip',
#   'rap',
#   'gangster',
#   'hardcore',
#   'political'],
#  ['rap', 'jazz', 'underground', 'ambeat'],
#  ['indie', 'poptimism', 'electropop'],
#  ['indie', 'art', 'rock', 'folk', 'pop', 'bubblegrunge'],
#  ['alternative', 'industrial', 'hop', 'room', 'hip', 'experimental', 'escape'],
#  ['art', 'chamber', 'pop', 'psych'],
#  ['chamber',
#   'indie',
#   'contemporary',
#   'world',
#   'uk',
#   'jazz',
#   'fourth',
#   'folk',
#   'psych'],
#  ['afropop', 'world', 'blues', 'desert', 'malian', 'pop', 'mande', 'afrobeat'],
#  ['country',
#   'songwriter',
#   'singer',
#   'mellow',
#   'blues',
#   'gold',
#   'traditional',
#   'rock',
#   'roots',
#   'folk',
#   'piedmont'],
#  ['new',
#   'americana',
#   'indie',
#   'holler',
#   'stomp',
#   'canadian',
#   'folk',
#   'pop',
#   'and'],
#  ['house', 'german'],
#  ['tropical', 'dance', 'house', 'edm', 'electropop', 'pop'],
#  ['indie', 'pop', 'electropop'],
#  ['alternative',
#   'modern',
#   'shimmer',
#   'indie',
#   'dance',
#   'auckland',
#   'indietronica',
#   'kiwi',
#   'rock',
#   'metropopolis',
#   'pop',
#   'electropop'],
#  ['new', 'dixieland', 'orleans', 'clarinet', 'jazz'],
#  ['neo', 'traditional', 'irish'],
#  ['indie', 'brisbane'],
#  ['punk', 'garage', 'australian'],
#  ['trip', 'hop', 'downtempo', 'livetronica', 'electronica'],
#  ['hop', 'hip', 'australian'],
#  ['alternative', 'dance', 'electronica'],
#  ['alternative', 'country', 'queer'],
#  ['indie',
#   'french',
#   'nouvelle',
#   'indietronica',
#   'chanson',
#   'francaise',
#   'rock',
#   'pop'],
#  ['francaise', 'variete', 'belgian', 'pop'],
#  ['neo', 'classical'],
#  ['minimal', 'hamburg', 'techno', 'microhouse', 'electronica', 'electronic'],
#  ['hop', 'k', 'rap', 'hip', 'battle', 'american', 'asian'],
#  ['deep',
#   'disco',
#   'tropical',
#   'house',
#   'dance',
#   'tech',
#   'edm',
#   'progressive',
#   'pop'],
#  ['psychedelic', 'neo'],
#  ['compositional',
#   'neoclassical',
#   'classical',
#   'icelandic',
#   'darkwave',
#   'bow',
#   'ambient',
#   'neo',
#   'pop'],
#  ['house', 'glitch', 'edm', 'filthstep', 'electro', 'complextro'],
#  ['indie', 'portland', 'holler', 'stomp', 'pop', 'and'],
#  ['songwriter', 'indie', 'singer', 'maine', 'rock', 'pop'],
#  ['miami', 'hop', 'drill', 'hip', 'dark', 'rap', 'trap', 'underground'],
#  ['trap', 'hop', 'hip', 'underground'],
#  ['reggae', 'fusion'],
#  ['teen', 'post', 'pop'],
#  ['scottish', 'indie'],
#  ['alternative',
#   'modern',
#   'vapor',
#   'shimmer',
#   'indie',
#   'dance',
#   'dream',
#   'chillwave',
#   'indietronica',
#   'soul',
#   'electropop',
#   'rock',
#   'metropopolis',
#   'pop'],
#  ['swedish', 'indie', 'art', 'dance', 'pop', 'electropop'],
#  ['modern', 'vapor', 'indie', 'garage', 'soul', 'rock', 'pop']]

# %%
type(all_genres[0])
# Out:
# list

# %%
genres_onemore = [' '.join(genre) for genre in all_genres]

genres_onemore
# Out:
# ['alternative modern indie garage revival supergroup blues rock',
#  'vapor twitch',
#  'alternative pop australian',
#  'fidget house bass australian',
#  'intelligent dance chillwave downtempo electronica indietronica music',
#  'downtempo bass',
#  'indie pop',
#  'modern alternative emo punk rock pixie pop electropop',
#  'pop australian',
#  'pop uk',
#  'alternative pop uk',
#  'alternative indie uk soul pop',
#  'urban post rb teen dance contemporary hip rap pop',
#  'hop christian houston hip rap',
#  'bedroom indie pop boston',
#  'jawaiian rock reggae',
#  'reggae fusion rock',
#  'aussietronica',
#  'aussietronica',
#  'alternative modern indie hop room escape soul hip canadian funk jazz',
#  'indie sydney',
#  'la pop',
#  'psychedelic punk garage australian neo psych',
#  'big nu trip jazztronica hop ninja downtempo beat electronica jazz',
#  'indie anthem brisbane folk',
#  'indie pop danish',
#  'melancholia chamber indie art baroque freak holler stomp chicago rock folk pop and',
#  'punk pop socal',
#  'poptimism tropical indie dance house edm electropop pop',
#  'deep tropical house edm pop',
#  'deep new americana indie retro soul funk folk',
#  'big tropical house dance edm room progressive electro pop electropop',
#  'alternative pop australian',
#  'punk indie garage rock australian',
#  'modern indie bedroom rock oakland pop',
#  'alternative new punk dance room rave escape electropop',
#  'alternative vapor tropical twitch rb indie house edm soul electropop',
#  'alternative rb indie contemporary soul uk gauze pop',
#  'post math indie rock asian taiwan instrumental southeast',
#  'hop conscious hip dmv rap pop',
#  'indie brisbane rock australian',
#  'trap hop hip australian',
#  'trap australian',
#  'deep tropical house dance edm electropop pop',
#  'hop hip australian',
#  'alternative modern emo rock pixie british pop',
#  'boston mellow rock neo pop',
#  'tropical house progressive gauze pop',
#  'shimmer art chillwave metropopolis pop electropop',
#  'indie kent',
#  'vapor pop',
#  'indie anthem folk australian',
#  'house uk',
#  'fusion contemporary progressive rock funk jazz',
#  'alternative vapor rb indie dance edm soul uk pop',
#  'bedroom indie pop boston',
#  'indie hop hip australian trap pop',
#  'indie dream pop australian',
#  'indie minneapolis rock pop bubblegrunge',
#  'house uplifting edm trance progressive',
#  'modern poptimism indie rock pop electropop',
#  'hop chicago conscious hip rap political southern pop',
#  'indie electropop',
#  'aussietronica',
#  'adelaide indie punk garage australian psych',
#  'indie house filter soul',
#  'indie ok indiecoustica christian',
#  'alternative electrofox poptimism northamptonshire shimmer indie dance metropopolis pop',
#  'rap melodic dfw',
#  'indie perth fremantle australian metropopolis pop',
#  'ambeat',
#  'ambeat',
#  'chillhop ambeat',
#  'rap underground',
#  'ambeat',
#  'beats focus',
#  'post emo indie aussie nsw australian hardcore newcastle',
#  'indie etherpop electropop rock folk pop',
#  'indie pop australian',
#  'bass lofi kawaii future beats',
#  'modern vapor poptimism indie dream indietronica soul electropop pop',
#  'alternative modern new punk dance indie rave rock',
#  'indie pop australian',
#  'downtempo japanese rap jazz chillhop',
#  'hop hip hawaiian',
#  'modern alternative bass rock trap traprun',
#  'punk indie garage perth fremantle rock australian',
#  'psychedelic neo australian psych',
#  'vancouver indie kelowna bc canadian',
#  'pop electropop',
#  'indie rock australian',
#  'fusion ska australian reggae jazz',
#  'chamber brooklyn small indie art freak room stomp holler rock folk pop and',
#  'new indie french indietronica touch electronica pop',
#  'indie vancouver rock canadian',
#  'vapor indie soul anthem folk',
#  'indie adelaide',
#  'drill trap australian aussie',
#  'drill aussie',
#  'compositional post rock american ambient',
#  'person indie art freak band rock one folk pop',
#  'nz pop',
#  'indonesian edm',
#  'indie indonesian',
#  'french new touch',
#  'alternative pop australian',
#  'indie minneapolis',
#  'deep new americana holler stomp and indiecoustica',
#  'alternative modern punk garage blues rock roots hard',
#  'nu trip jazztronica hop ninja downtempo electronica jazz',
#  'indie garage soul electronica future',
#  'alternative trip permanent dance art hop wave icelandic vocal experimental electronica metropopolis pop',
#  'bass chillwave ninja electronica microhouse wonky music',
#  'alternative rb indie art la room soul afrofuturism escape pop',
#  'indie oc',
#  'alternative indie rb',
#  'rap hop hip pittsburgh',
#  'indie art chillwave soul electronica pop',
#  'modern fusion dancehall rock reggae roots lovers',
#  'indie dream shoegaze metropopolis pop',
#  'indie tassie',
#  'alternative modern nu stoner scene metal blues desert rock palm',
#  'alternative modern new indie dance punk rave rock francais independant pop',
#  'vapor poptimism tropical shimmer indie house auckland indietronica soul electropop etherpop metropopolis nz pop',
#  'hop hip german rap pop',
#  'pop german rb',
#  'indie pop indiecoustica cafe',
#  'alternative vapor rb indie chill soul nyc pop',
#  'indie anthem folk',
#  'modern alternative poptimism indie minneapolis rock pop',
#  'vapor poptimism indie soul electropop pop',
#  'modern ska punk',
#  'indie adelaide',
#  'indie pop australian',
#  'chillstep vapor twitch',
#  'nz pop',
#  'punk indie garage australian pop',
#  'indie rock pop german',
#  'alternative rb indie cafe bedroom pop',
#  'alternative rb indie neo room soul escape',
#  'hop hip atl rap pop',
#  'alternative hop sudanese hip dmv rap pop',
#  'alternative new punk dance rave electronica',
#  'indie rock australian',
#  'alternative modern indie holler stomp rock folk and',
#  'indie seattle',
#  'post queen teen dance room trap pop escape electropop',
#  'indie nashville',
#  'reggae rock',
#  'jamtronica band jam livetronica',
#  'indie nottingham metropopolis',
#  'vapor shimmer indie art grave chillwave indietronica edmonton wave soul canadian metropopolis pop electropop',
#  'downtempo bass',
#  'indie jazz pop soul',
#  'alternative uk soul british pop',
#  'indietronica electropop australian edm',
#  'nu trip hop downtempo electronica jazz',
#  'birmingham hop hip',
#  'indie vienna',
#  'indie brooklyn baroque pop',
#  'whittle shimmer indie holler stomp metropopolis folk pop and',
#  'indie jacksonville rock modern',
#  'indie freak holler stomp philly folk and',
#  'alternative rock pop modern',
#  'hop hip underground',
#  'synthpop new indie french touch soul pop indietronica',
#  'modern jazz danish',
#  'electra',
#  'reggae fusion rock',
#  'vapor electropop metropopolis pop',
#  'french new touch',
#  'deep indie hop hip rap pop underground',
#  'beats chillhop lofi',
#  'birmingham modern alternative indie rock english',
#  'rap pop',
#  'alternative big nu jazztronica hop ninja beat hip electronica turntablism jazz',
#  'indie rock pop',
#  'indie pop australian soul',
#  'cyberpunk synthwave',
#  'spacewave popwave synthwave',
#  'alternative shimmer indie australian pop',
#  'alternative big trip dance hop downtempo beat electronica electropop',
#  'indie nyc pop',
#  'hop conscious hip comic',
#  'dance australian',
#  'punk indie garage brisbane australian',
#  'alternative queen indie hop soul room uk hip trap escape',
#  'motown quiet soul chicago southern storm funk memphis classic',
#  'cali alternative modern rock rap',
#  'bounce new queen hop room hip lgbtq orleans rap trap escape',
#  'minnesota queen dance hop room hip rap trap escape pop',
#  'retro soul',
#  'new indie french touch pop indietronica',
#  'mpb nova',
#  'modern rock spanish',
#  'alternative nu new disco indie dance soul rave',
#  'la pop',
#  'tropical dance house edm electropop pop',
#  'post teen dance viral pop electropop',
#  'compositional new nu contemporary tribe quartet electronica ambient british jazz',
#  'modern hop hip rock comic rap pop abstract',
#  'alternative aussietronica vapor rb indie soul electropop',
#  'alternative dance vapor soul',
#  'indie australian',
#  'trap australian',
#  'francais independant rock',
#  'small indie art chillwave room area rock oakland folk pop bay',
#  'indie art eugene rock philly pop bubblegrunge',
#  'indie pop australian',
#  'reggae fusion rock',
#  'austindie pop soul',
#  'petersburg indie fl st',
#  'hyphy coast trap rap gangster west',
#  'french arabic jazz trumpet',
#  'aussietronica tropical indie house dance edm soul gauze pop',
#  'synthpop swedish dance candy metropopolis pop electropop',
#  'nz pop',
#  'big tropical house dance uplifting edm room progressive trance electro pop',
#  'dream korean pop',
#  'modern alternative poptimism indie la rock pop',
#  'indie pop cafe',
#  'rock instrumental',
#  'vapor indie soul australian electropop',
#  'organic new french minimal touch hamburg techno microhouse electronica electronic ambient pop',
#  'hop hip australian',
#  'emo punk candy pixie pop',
#  'house disco vocal filter',
#  'classical performance jazz turkish piano',
#  'performance taiwan classical',
#  'electropop australian',
#  'vapor pop',
#  'bedroom indie pop bubblegrunge',
#  'reggae fusion australian',
#  'indie jazz soul',
#  'alternative modern synthpop new shimmer indie dance punk indietronica rave rock canadian metropopolis pop neo electropop',
#  'indie wonky chillwave jazz',
#  'indie rock australian',
#  'alternative hop southern south trap conscious hip atl hardcore rap gangster dirty',
#  'alternative coast hop bronx east school conscious hip turntablism rap gangster hardcore political old',
#  'alternative hop southern neo soul chicago conscious hip rap gangster hardcore political',
#  'rap jazz underground ambeat',
#  'indie poptimism electropop',
#  'indie art rock folk pop bubblegrunge',
#  'alternative industrial hop room hip experimental escape',
#  'art chamber pop psych',
#  'chamber indie contemporary world uk jazz fourth folk psych',
#  'afropop world blues desert malian pop mande afrobeat',
#  'country songwriter singer mellow blues gold traditional rock roots folk piedmont',
#  'new americana indie holler stomp canadian folk pop and',
#  'house german',
#  'tropical dance house edm electropop pop',
#  'indie pop electropop',
#  'alternative modern shimmer indie dance auckland indietronica kiwi rock metropopolis pop electropop',
#  'new dixieland orleans clarinet jazz',
#  'neo traditional irish',
#  'indie brisbane',
#  'punk garage australian',
#  'trip hop downtempo livetronica electronica',
#  'hop hip australian',
#  'alternative dance electronica',
#  'alternative country queer',
#  'indie french nouvelle indietronica chanson francaise rock pop',
#  'francaise variete belgian pop',
#  'neo classical',
#  'minimal hamburg techno microhouse electronica electronic',
#  'hop k rap hip battle american asian',
#  'deep disco tropical house dance tech edm progressive pop',
#  'psychedelic neo',
#  'compositional neoclassical classical icelandic darkwave bow ambient neo pop',
#  'house glitch edm filthstep electro complextro',
#  'indie portland holler stomp pop and',
#  'songwriter indie singer maine rock pop',
#  'miami hop drill hip dark rap trap underground',
#  'trap hop hip underground',
#  'reggae fusion',
#  'teen post pop',
#  'scottish indie',
#  'alternative modern vapor shimmer indie dance dream chillwave indietronica soul electropop rock metropopolis pop',
#  'swedish indie art dance pop electropop',
#  'modern vapor indie garage soul rock pop']

# %%
genres_final = ' '.join(genres_onemore)

# %%
genres_final
# Out:
# 'alternative modern indie garage revival supergroup blues rock vapor twitch alternative pop australian fidget house bass australian intelligent dance chillwave downtempo electronica indietronica music downtempo bass indie pop modern alternative emo punk rock pixie pop electropop pop australian pop uk alternative pop uk alternative indie uk soul pop urban post rb teen dance contemporary hip rap pop hop christian houston hip rap bedroom indie pop boston jawaiian rock reggae reggae fusion rock aussietronica aussietronica alternative modern indie hop room escape soul hip canadian funk jazz indie sydney la pop psychedelic punk garage australian neo psych big nu trip jazztronica hop ninja downtempo beat electronica jazz indie anthem brisbane folk indie pop danish melancholia chamber indie art baroque freak holler stomp chicago rock folk pop and punk pop socal poptimism tropical indie dance house edm electropop pop deep tropical house edm pop deep new americana indie retro soul funk folk big tropical house dance edm room progressive electro pop electropop alternative pop australian punk indie garage rock australian modern indie bedroom rock oakland pop alternative new punk dance room rave escape electropop alternative vapor tropical twitch rb indie house edm soul electropop alternative rb indie contemporary soul uk gauze pop post math indie rock asian taiwan instrumental southeast hop conscious hip dmv rap pop indie brisbane rock australian trap hop hip australian trap australian deep tropical house dance edm electropop pop hop hip australian alternative modern emo rock pixie british pop boston mellow rock neo pop tropical house progressive gauze pop shimmer art chillwave metropopolis pop electropop indie kent vapor pop indie anthem folk australian house uk fusion contemporary progressive rock funk jazz alternative vapor rb indie dance edm soul uk pop bedroom indie pop boston indie hop hip australian trap pop indie dream pop australian indie minneapolis rock pop bubblegrunge house uplifting edm trance progressive modern poptimism indie rock pop electropop hop chicago conscious hip rap political southern pop indie electropop aussietronica adelaide indie punk garage australian psych indie house filter soul indie ok indiecoustica christian alternative electrofox poptimism northamptonshire shimmer indie dance metropopolis pop rap melodic dfw indie perth fremantle australian metropopolis pop ambeat ambeat chillhop ambeat rap underground ambeat beats focus post emo indie aussie nsw australian hardcore newcastle indie etherpop electropop rock folk pop indie pop australian bass lofi kawaii future beats modern vapor poptimism indie dream indietronica soul electropop pop alternative modern new punk dance indie rave rock indie pop australian downtempo japanese rap jazz chillhop hop hip hawaiian modern alternative bass rock trap traprun punk indie garage perth fremantle rock australian psychedelic neo australian psych vancouver indie kelowna bc canadian pop electropop indie rock australian fusion ska australian reggae jazz chamber brooklyn small indie art freak room stomp holler rock folk pop and new indie french indietronica touch electronica pop indie vancouver rock canadian vapor indie soul anthem folk indie adelaide drill trap australian aussie drill aussie compositional post rock american ambient person indie art freak band rock one folk pop nz pop indonesian edm indie indonesian french new touch alternative pop australian indie minneapolis deep new americana holler stomp and indiecoustica alternative modern punk garage blues rock roots hard nu trip jazztronica hop ninja downtempo electronica jazz indie garage soul electronica future alternative trip permanent dance art hop wave icelandic vocal experimental electronica metropopolis pop bass chillwave ninja electronica microhouse wonky music alternative rb indie art la room soul afrofuturism escape pop indie oc alternative indie rb rap hop hip pittsburgh indie art chillwave soul electronica  ...

# %%
genres_final = genres_final.replace('rb', 'r&b')

# %% [markdown]
# Now we can start with the wordcloud.

# %%
mask = np.array(Image.open('logo.jpeg'))

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                      background_color = 'black', 
                      min_font_size = 1, mask=mask).generate(genres_final)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)

plt.show()
